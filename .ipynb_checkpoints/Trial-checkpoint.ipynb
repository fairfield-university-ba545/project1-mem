# %%
# imports
import pandas as pd
import numpy as np
import os

import pandas as pd

data = pd.read_excel('Competition1_raw_data.xlsx')
data.head()
# Out:
#      I1                                  I2    I3 P(IPO) P(H) P(L) P(1Day)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674     10  9.5  8.5   11.87
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834      8   10    8    7.25
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834      7   14   12     6.7
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834   11.5   16   14   12.39
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492     21   21   19    56.6
#
#     C1 C2    C3  ...        C6       C7   T1     T2     T3   T4    T5  S1  \
# 0  122  1  3.43  ...  10600000   51.345  470  12719  11560  301   690  62
# 1  259  0 -1.62  ...   2400000   25.936  791  21792  19585  510  1120  71
# 2   90  1 -1.24  ...   5000000    7.378  201   5262   4785  128   325  61
# 3  209  1 -0.91  ...   4500000    8.526  328   8259   7574  177   509  80
# 4   80  1  0.07  ...   8250000  632.298  572  14830  13176  336   720  67
#
#     S2   S3
# 0  117  139
# 1  242  237
# 2   33   60
# 3   59  110
# 4  149  167
#
# [5 rows x 22 columns]

# %%
data = data.replace('-',np.nan)

# %%
data = data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 593 entries, 0 to 681
# Data columns (total 22 columns):
# I1         593 non-null object
# I2         593 non-null object
# I3         593 non-null object
# P(IPO)     593 non-null float64
# P(H)       593 non-null float64
# P(L)       593 non-null float64
# P(1Day)    593 non-null float64
# C1         593 non-null float64
# C2         593 non-null float64
# C3         593 non-null float64
# C4         593 non-null float64
# C5         593 non-null float64
# C6         593 non-null float64
# C7         593 non-null float64
# T1         593 non-null float64
# T2         593 non-null float64
# T3         593 non-null float64
# T4         593 non-null float64
# T5         593 non-null float64
# S1         593 non-null float64
# S2         593 non-null float64
# S3         593 non-null float64
# dtypes: float64(19), object(3)
# memory usage: 106.6+ KB

# %%
#drop rows that P(IPO) has dashes in
data.drop(10, inplace=True)
data.drop(86, inplace=True)
data.drop(330, inplace=True)
data.drop(400, inplace=True)
data.drop(597, inplace=True)

data.drop(215, inplace=True)
data.drop(268, inplace=True)
data.drop(490, inplace=True)
data.drop(560, inplace=True)
data.drop(614, inplace=True)

data.drop(115, inplace=True)
data.drop(123, inplace=True)
data.drop(203, inplace=True)
data.drop(217, inplace=True)
data.drop(286, inplace=True)
data.drop(357, inplace=True)
data.drop(401, inplace=True)
data.drop(410, inplace=True)
data.drop(496, inplace=True)
data.drop(503, inplace=True)
data.drop(615, inplace=True)
data.drop(675, inplace=True)

# I3 to integers
#data['I3'] = data['I3'].str.strip()
data['I3'] = pd.to_numeric(data['I3'], errors='coerce')
data['I3'].index = data['I3'].index.astype(int)

# %%
def assign_bins(I3):
    if (I3 >= 100) and (I3 <= 999):       
        return(1)
    if (I3 >= 1000) and (I3 <= 1499):       
        return(2)
    if (I3 >= 1500) and (I3 <= 1799):       
        return(3)
    if (I3 >= 2000) and (I3 <= 3999):       
        return(4)
    if (I3 >= 4000) and (I3 <= 4999):       
        return(5)
    if (I3 >= 5000) and (I3 <= 5199):       
        return(6)
    if (I3 >= 5200) and (I3 <= 5999):       
        return(7)
    if (I3 >= 6000) and (I3 <= 6799):       
        return(8)
    if (I3 >= 7000) and (I3 <= 8999):       
        return(9)
    if (I3 >= 9100) and (I3 <= 9729):       
        return(10)
    if (I3 >= 9900) and (I3 <= 9999):       
        return(11)
    else:       
        return(0)

data['bins'] = data['I3'].apply(assign_bins)
data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-c62c6db8337a> in <module>
#      25         return(0)
#      26
# ---> 27 data['bins'] = data['I3'].apply(assign_bins)
#      28 data.head()
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-3-c62c6db8337a> in assign_bins(I3)
#       1 def assign_bins(I3):
# ----> 2     if (I3 >= 100) and (I3 <= 999):
#       3         return(1)
#       4     if (I3 >= 1000) and (I3 <= 1499):
#       5         return(2)
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
#data.loc[data['T4'] == '-'] 
#data.drop(217,inplace=True)
#percent of long sentences
data["T1prime"] = data["T4"].astype(float)/data["T1"].astype(float)
#percent of real words
data["T3prime"] = data["T3"].astype(float)/data["T2"].astype(float)
#percent of long words
data["T4prime"] = data["T5"].astype(float)/data["T2"].astype(float)
#percent of positive words
data["S1prime"] = data["S1"].astype(float)/data["T2"].astype(float)
#percent of negative words
data["S2prime"] = data["S2"].astype(float)/data["T2"].astype(float)
#percent of uncertain words
data["S3prime"] = data["S2"].astype(float)/data["T2"].astype(float)
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b87b4564c0de> in <module>
#       2 #data.drop(217,inplace=True)
#       3 #percent of long sentences
# ----> 4 data["T1prime"] = data["T4"].astype(float)/data["T1"].astype(float)
#       5 #percent of real words
#       6 data["T3prime"] = data["T3"].astype(float)/data["T2"].astype(float)
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     727     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     728         # Explicit copy, or required since NumPy can't view from / to object.
# --> 729         return arr.astype(dtype, copy=True)
#     730
#     731     return arr.view(dtype)
#
# ValueError: could not convert string to float: '-'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 22 columns):
# I1         682 non-null object
# I2         682 non-null object
# I3         682 non-null object
# P(IPO)     682 non-null object
# P(H)       682 non-null object
# P(L)       682 non-null object
# P(1Day)    682 non-null object
# C1         682 non-null object
# C2         682 non-null object
# C3         682 non-null object
# C4         682 non-null object
# C5         682 non-null object
# C6         682 non-null object
# C7         682 non-null object
# T1         682 non-null object
# T2         682 non-null object
# T3         682 non-null object
# T4         682 non-null object
# T5         682 non-null object
# S1         682 non-null object
# S2         682 non-null object
# S3         682 non-null object
# dtypes: object(22)
# memory usage: 117.3+ KB

# %%
# dashes rows to be dropped for dashes --> P(IPO), P(H), P(L), P(1Day), C3
indexNames1 = data[data['P(IPO)'] == '-' ].index
indexNames2 = data[data['P(H)'] == '-' ].index
indexNames3 = data[data['P(1Day)'] == '-' ].index
indexNames4 = data[data['C3'] == '-' ].index

# Delete these row indexes from dataFrame
data.drop(indexNames1 , inplace=True)
data.drop(indexNames2 , inplace=True)
data.drop(indexNames3 , inplace=True)
data.drop(indexNames4 , inplace=True)

# %%
indexNames5 = data[data['C7'] == '-' ].index
data.drop(indexNames5 , inplace=True)

# %%
# changing to correct type --> to continous 
cols = ['P(IPO)','P(H)','P(L)','P(1Day)','C1','C3','C4','C5','C6','C7','T1','T2','T3','T4','T5','S1','S2','S3']
data[cols] = data[cols].astype(float)
# to int 
data['C2'] = data['C2'].astype(int)

# %%
# P(mid) calculation and add it to the column 
# P(mid) = (P(H)+P(L))/2
data['I3'] = data['I3'].astype(str)
data['C2'] = data['C2'].astype(int)
data['P(mid)'] = (data['P(H)'] - data['P(L)'])/2

# targets to be calculated
# make it equal to P(IPO) then we will just replace
data['Y1'] = data['P(IPO)']
data['Y2'] = data['P(IPO)']

# replace Y1 and change dtype to binary
data.loc[(data['Y1'] < data['P(mid)']),'Y1'] = 1
data.loc[(data['Y1'] > data['P(mid)']),'Y1'] = 0
data['Y1'] = data['Y1'].astype(int)

# replace Y2
data.loc[(data['Y2'] < data['P(1Day)']),'Y2'] = 1
data.loc[(data['Y2'] > data['P(1Day)']),'Y2'] = 0
data['Y2'] = data['Y2'].astype(int)

# Control values to be calculated
data['C3`'] = data['C3']
data['C3`'] = np.where((data['C3'] > 0),1,data['C3`'])
data['C3`'] = np.where((data['C3'] < 0),0,data['C3`'])
data['C3`'] = data['C3`'].astype(int)

# C5`
data['C5`'] = data['C5']/data['C6']

# C6`
data['C6calc'] = ((data['P(IPO)'] - data['P(mid)']) / data['P(mid)']) * 1
data['C6`'] = 0
data['C6`'] = np.where((data['P(IPO)'] > data['P(mid)']),data['C6calc'],data['C6`'])
data['C6`'] = np.where((data['P(IPO)'] < data['P(mid)']),0,data['C6`'])
data['C6`'] = np.where((data['P(mid)']==0),0,data['C6`'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 593 entries, 0 to 681
# Data columns (total 29 columns):
# I1         593 non-null object
# I2         593 non-null object
# I3         593 non-null object
# P(IPO)     593 non-null float64
# P(H)       593 non-null float64
# P(L)       593 non-null float64
# P(1Day)    593 non-null float64
# C1         593 non-null float64
# C2         593 non-null int64
# C3         593 non-null float64
# C4         593 non-null float64
# C5         593 non-null float64
# C6         593 non-null float64
# C7         593 non-null float64
# T1         593 non-null float64
# T2         593 non-null float64
# T3         593 non-null float64
# T4         593 non-null float64
# T5         593 non-null float64
# S1         593 non-null float64
# S2         593 non-null float64
# S3         593 non-null float64
# P(mid)     593 non-null float64
# Y1         593 non-null int64
# Y2         593 non-null int64
# C3`        593 non-null int64
# C5`        593 non-null float64
# C6calc     593 non-null float64
# C6`        593 non-null float64
# dtypes: float64(22), int64(4), object(3)
# memory usage: 139.0+ KB

# %%
data.columns
# Out:
# Index(['I1', 'I2', 'I3', 'P(IPO)', 'P(H)', 'P(L)', 'P(1Day)', 'C1', 'C2', 'C3',
#        'C4', 'C5', 'C6', 'C7', 'T1', 'T2', 'T3', 'T4', 'T5', 'S1', 'S2', 'S3',
#        'P(mid)', 'Y1', 'Y2', 'C3`', 'C5`', 'C6calc', 'C6`'],
#       dtype='object')

# %%
data.head(5)
# Out:
#      I1                                  I2    I3  P(IPO)  P(H)  P(L)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674    10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834     8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834     7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834    11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492    21.0  21.0  19.0
#
#      P(1Day)     C1  C2    C3  ...    S1     S2     S3  P(mid)  Y1  Y2  C3`  \
# 0  11.870000  122.0   1  3.43  ...  62.0  117.0  139.0     0.5   0   1    1
# 1   7.250000  259.0   0 -1.62  ...  71.0  242.0  237.0     1.0   0   0    0
# 2   6.700000   90.0   1 -1.24  ...  61.0   33.0   60.0     1.0   0   0    0
# 3  12.390000  209.0   1 -0.91  ...  80.0   59.0  110.0     1.0   0   1    0
# 4  56.599998   80.0   1  0.07  ...  67.0  149.0  167.0     1.0   0   1    1
#
#          C5`  C6calc   C6`
# 0   3.864345    19.0  19.0
# 1  12.028832     7.0   7.0
# 2   3.369134     6.0   6.0
# 3   3.299697    10.5  10.5
# 4   3.726269    20.0  20.0
#
# [5 rows x 29 columns]

# %%
data.isna().sum()
# Out:
# I1         0
# I2         0
# I3         0
# P(IPO)     0
# P(H)       0
# P(L)       0
# P(1Day)    0
# C1         0
# C2         0
# C3         0
# C4         0
# C5         0
# C6         0
# C7         0
# T1         0
# T2         0
# T3         0
# T4         0
# T5         0
# S1         0
# S2         0
# S3         0
# P(mid)     0
# Y1         0
# Y2         0
# C3`        0
# C5`        0
# C6calc     0
# C6`        0
# dtype: int64

# %%
import numpy as np

# %%
np.isfinite(data).all()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-3c7f8bb0d956> in <module>
# ----> 1 np.isfinite(data).all()
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
data.to_csv('OMG')
