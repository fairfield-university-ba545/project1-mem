# %%
# imports
import pandas as pd
import numpy as np

# %% [markdown]
# To do:
# - Drop dashes for those columns you use to calculate the target variables (Y1 and Y2) --> drop rows --> MEGAN
# - I3 --> binning --> tech/non-tech, other --> MEGAN
# - Set up the ratios (look at the hints at instructions) --> MARCUS
# - How to handle other missing values --> look at the photo --> ERIK
#
# - Baseline test --> BY MONAY HAVE THE BASELINE TEST
#
# - Normality test (shapiro, histograms, only look the continous) --> function kurtosis --> ERIK
# - Normalization (only continous) (log, etc.) --> aply it based on how the histograms look like (depending on the skew)
# - Standardization (if with z score we have to normalize it, min-max no need)
# - run test and use different columns --> do not use leakers (P, and T's, and S's you use for the calculations)

# %% [markdown]
# # Need to do some calculation for Y, S,T (use ratios for prime)
# # purple group they in text --> not as useful --> not all of them are ID like features some of them might be useful
#     # 1 tend to be very useful

# %%
# CHECK HIGH AND LOW !!! --> INVALID VALUES
# TRULY MISSING VALUES??? CHECK
# are HIGH LOW CONNECTED TO NULL VALUES 
# WHAT DOES - mean --> when does it happen 
# high and low of the IPO
# Pmid fair estimation of P(H) or P(L) --> UNDERPRICING DETECTING (Y1, Y2)

# %%
data = pd.read_excel('Competition1_raw_data.xlsx')
                    #dtype={'P(IPO)': float, 'P(1Day)': float})
# define dashes as missing --> 0 or NaN
data.head(5)
# Out:
#      I1                                  I2    I3 P(IPO) P(H) P(L) P(1Day)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674     10  9.5  8.5   11.87
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834      8   10    8    7.25
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834      7   14   12     6.7
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834   11.5   16   14   12.39
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492     21   21   19    56.6
#
#     C1 C2    C3  ...        C6       C7   T1     T2     T3   T4    T5  S1  \
# 0  122  1  3.43  ...  10600000   51.345  470  12719  11560  301   690  62
# 1  259  0 -1.62  ...   2400000   25.936  791  21792  19585  510  1120  71
# 2   90  1 -1.24  ...   5000000    7.378  201   5262   4785  128   325  61
# 3  209  1 -0.91  ...   4500000    8.526  328   8259   7574  177   509  80
# 4   80  1  0.07  ...   8250000  632.298  572  14830  13176  336   720  67
#
#     S2   S3
# 0  117  139
# 1  242  237
# 2   33   60
# 3   59  110
# 4  149  167
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 22 columns):
# I1         682 non-null object
# I2         682 non-null object
# I3         682 non-null object
# P(IPO)     682 non-null object
# P(H)       682 non-null object
# P(L)       682 non-null object
# P(1Day)    682 non-null object
# C1         682 non-null object
# C2         682 non-null object
# C3         682 non-null object
# C4         682 non-null object
# C5         682 non-null object
# C6         682 non-null object
# C7         682 non-null object
# T1         682 non-null object
# T2         682 non-null object
# T3         682 non-null object
# T4         682 non-null object
# T5         682 non-null object
# S1         682 non-null object
# S2         682 non-null object
# S3         682 non-null object
# dtypes: object(22)
# memory usage: 117.3+ KB

# %%
# Companies that have dashes in some places 
data[(data['P(1Day)']=='-') & (data['P(IPO)']=='-') & (data['P(H)']=='-')& (data['C1']=='-')& (data['C2']=='-')& 
     (data['C3']=='-')& (data['C4']=='-')& (data['C5']=='-')& (data['C6']=='-')& (data['C7']=='-')& (data['I3']=='-')]
# Out:
#        I1                                           I2 I3 P(IPO) P(H) P(L)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC  -      -    -    -
# 86    BLT                     BLOUNT INTERNATIONAL INC  -      -    -    -
# 330   KFI                   KKR Financial Holdings LLC  -      -    -    -
# 400  NAUH  National American University Holdings, Inc.  -      -    -    -
# 597  TRMM                       Access to Money, Inc.   -      -    -    -
#
#     P(1Day) C1 C2 C3  ... C6 C7   T1     T2     T3   T4     T5  S1   S2   S3
# 10        -  -  -  -  ...  -  -  332   7534   6747  169    263  51   65   74
# 86        -  -  -  -  ...  -  -  538  12732  11126  301    631  94  172  116
# 330       -  -  -  -  ...  -  -  246    527   9046  355  10277  64   48  123
# 400       -  -  -  -  ...  -  -  290   8454   7137  192    384  45   68  139
# 597       -  -  -  -  ...  -  -  494  12004  10226  277    560  46  100   91
#
# [5 rows x 22 columns]

# %%
# I3
data.loc[data['I3'] == '-']
# Out:
# Empty DataFrame
# Columns: [I1, I2, I3, P(IPO), P(H), P(L), P(1Day), C1, C2, C3, C4, C5, C6, C7, T1, T2, T3, T4, T5, S1, S2, S3, IPO/H_dist, IPO/L_dist, H/L_dist, P(IPO)/P(1Day)_dist, P(mid), Y1, Y2, C3`, C5`, C6calc, C6`]
# Index: []
#
# [0 rows x 33 columns]

# %%
# P(IPO)
data.loc[data['P(IPO)'] == '-']
# Out:
#        I1                                           I2 I3 P(IPO) P(H) P(L)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC  -      -    -    -
# 86    BLT                     BLOUNT INTERNATIONAL INC  -      -    -    -
# 330   KFI                   KKR Financial Holdings LLC  -      -    -    -
# 400  NAUH  National American University Holdings, Inc.  -      -    -    -
# 597  TRMM                       Access to Money, Inc.   -      -    -    -
#
#     P(1Day) C1 C2 C3  ... C6 C7   T1     T2     T3   T4     T5  S1   S2   S3
# 10        -  -  -  -  ...  -  -  332   7534   6747  169    263  51   65   74
# 86        -  -  -  -  ...  -  -  538  12732  11126  301    631  94  172  116
# 330       -  -  -  -  ...  -  -  246    527   9046  355  10277  64   48  123
# 400       -  -  -  -  ...  -  -  290   8454   7137  192    384  45   68  139
# 597       -  -  -  -  ...  -  -  494  12004  10226  277    560  46  100   91
#
# [5 rows x 22 columns]

# %%
# P(H)
data.loc[data['P(H)'] == '-']
# Out:
#        I1                                           I2    I3 P(IPO) P(H) P(L)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC     -      -    -    -
# 86    BLT                     BLOUNT INTERNATIONAL INC     -      -    -    -
# 215  ESEA                               EUROSEAS LTD.   4412      7    -    -
# 268   GSL                            GLOBAL SIGNAL INC     -     18    -    -
# 330   KFI                   KKR Financial Holdings LLC     -      -    -    -
# 400  NAUH  National American University Holdings, Inc.     -      -    -    -
# 490   RCH                            CHINA CGAME, INC.     -    3.5    -    -
# 560  STRL                 STERLING CONSTRUCTION CO INC  1600     15    -    -
# 597  TRMM                       Access to Money, Inc.      -      -    -    -
# 614  TZOO                                TRAVELZOO INC     -    3.5    -    -
#
#     P(1Day) C1 C2 C3  ...       C6 C7   T1     T2     T3   T4     T5  S1   S2  \
# 10        -  -  -  -  ...        -  -  332   7534   6747  169    263  51   65
# 86        -  -  -  -  ...        -  -  538  12732  11126  301    631  94  172
# 215       -  -  -  -  ...  9602340  -  521  12812  11190  285    545  72   60
# 268       -  -  -  -  ...  7000000  -  631  19479  17409  451    976  71  252
# 330       -  -  -  -  ...        -  -  246    527   9046  355  10277  64   48
# 400       -  -  -  -  ...        -  -  290   8454   7137  192    384  45   68
# 490       -  -  -  -  ...   737000  -  322   9820   8893  230    410  61   92
# 560       -  -  -  -  ...  2021758  -  310   7195   6393  172    325  44   65
# 597       -  -  -  -  ...        -  -  494  12004  10226  277    560  46  100
# 614       -  -  -  -  ...        -  -  146   3600   3189   88    181   5   26
#
#       S3
# 10    74
# 86   116
# 215  121
# 268  155
# 330  123
# 400  139
# 490   91
# 560   85
# 597   91
# 614   38
#
# [10 rows x 22 columns]

# %%
# P(L)
data.loc[data['P(L)'] == '-']
# Out:
#        I1                                           I2    I3 P(IPO) P(H) P(L)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC     -      -    -    -
# 86    BLT                     BLOUNT INTERNATIONAL INC     -      -    -    -
# 215  ESEA                               EUROSEAS LTD.   4412      7    -    -
# 268   GSL                            GLOBAL SIGNAL INC     -     18    -    -
# 330   KFI                   KKR Financial Holdings LLC     -      -    -    -
# 400  NAUH  National American University Holdings, Inc.     -      -    -    -
# 490   RCH                            CHINA CGAME, INC.     -    3.5    -    -
# 560  STRL                 STERLING CONSTRUCTION CO INC  1600     15    -    -
# 597  TRMM                       Access to Money, Inc.      -      -    -    -
# 614  TZOO                                TRAVELZOO INC     -    3.5    -    -
#
#     P(1Day) C1 C2 C3  ...       C6 C7   T1     T2     T3   T4     T5  S1   S2  \
# 10        -  -  -  -  ...        -  -  332   7534   6747  169    263  51   65
# 86        -  -  -  -  ...        -  -  538  12732  11126  301    631  94  172
# 215       -  -  -  -  ...  9602340  -  521  12812  11190  285    545  72   60
# 268       -  -  -  -  ...  7000000  -  631  19479  17409  451    976  71  252
# 330       -  -  -  -  ...        -  -  246    527   9046  355  10277  64   48
# 400       -  -  -  -  ...        -  -  290   8454   7137  192    384  45   68
# 490       -  -  -  -  ...   737000  -  322   9820   8893  230    410  61   92
# 560       -  -  -  -  ...  2021758  -  310   7195   6393  172    325  44   65
# 597       -  -  -  -  ...        -  -  494  12004  10226  277    560  46  100
# 614       -  -  -  -  ...        -  -  146   3600   3189   88    181   5   26
#
#       S3
# 10    74
# 86   116
# 215  121
# 268  155
# 330  123
# 400  139
# 490   91
# 560   85
# 597   91
# 614   38
#
# [10 rows x 22 columns]

# %%
# P(1Day)
data.loc[data['P(1Day)'] == '-']
# Out:
#        I1                                              I2    I3 P(IPO) P(H)  \
# 10   ADKU                      ADCARE HEALTH SYSTEMS, INC     -      -    -
# 86    BLT                        BLOUNT INTERNATIONAL INC     -      -    -
# 115  CELM                      CHINA ELECTRIC MOTOR, INC.  3621    4.5  6.5
# 123   CIL  China Intelligent Lighting & Electronics, Inc.  3640      3    5
# 203  ELMD                               Electromed, Inc.   3845      4    6
# 215  ESEA                                  EUROSEAS LTD.   4412      7    -
# 217  EURX                                    EURAND N.V.   2834     16   19
# 268   GSL                               GLOBAL SIGNAL INC     -     18    -
# 286   HPJ                   Highpower International, Inc.  3690   3.25    4
# 330   KFI                      KKR Financial Holdings LLC     -      -    -
# 357  LZEN                      Lizhan Environmental Corp   2200      4    6
# 400  NAUH     National American University Holdings, Inc.     -      -    -
# 401   NBY                   NovaBay Pharmaceuticals, Inc.  2834      4    6
# 410   NIV        NIVS IntelliMedia Technology Group, Inc.  3651    3.5    4
# 490   RCH                               CHINA CGAME, INC.     -    3.5    -
# 496  RGLS                       Regulus Therapeutics Inc.  2834      4   12
# 503  RNIN                             CREATIVE REALITIES,  7373      4    5
# 560  STRL                    STERLING CONSTRUCTION CO INC  1600     15    -
# 597  TRMM                          Access to Money, Inc.      -      -    -
# 614  TZOO                                   TRAVELZOO INC     -    3.5    -
# 615  TZYM                       Ocera Therapeutics, Inc.   2834      4   13
# 675  ZGNX                                   ZOGENIX, INC.  2834      4   14
#
#      P(L) P(1Day) C1 C2       C3  ...        C6       C7   T1     T2     T3  \
# 10      -       -  -  -        -  ...         -        -  332   7534   6747
# 86      -       -  -  -        -  ...         -        -  538  12732  11126
# 115   5.5       -  -  -        -  ...   5000000        -  351  10352   9296
# 123     4       -  -  -   59.261  ...   3350000   59.261  406  12065  11056
# 203     4       -  -  -   12.999  ...   1700000   12.999  224   6146   5551
# 215     -       -  -  -        -  ...   9602340        -  521  12812  11190
# 217    17       -  -  -  109.336  ...   7000000  109.336    -      -      -
# 268     -       -  -  -        -  ...   7000000        -  631  19479  17409
# 286     3       -  -  -   73.262  ...    525000   73.262  377  10731   9703
# 330     -       -  -  -        -  ...         -        -  246    527   9046
# 357     5       -  -  -   21.612  ...   2500000   21.612  373  10261   9189
# 400     -       -  -  -        -  ...         -        -  290   8454   7137
# 401     4       -  -  -    1.533  ...   5000000    1.533  382   9959   9215
# 410  3.25       -  -  -  101.048  ...    550000  101.048  451  12594  11210
# 490     -       -  -  -        -  ...    737000        -  322   9820   8893
# 496    10       -  -  -   13.789  ...  11250000   13.789  344  11091  10333
# 503     4       -  -  -  710.216  ...   4500000  710.216  199   5073   4395
# 560     -       -  -  -        -  ...   2021758        -  310   7195   6393
# 597     -       -  -  -        -  ...         -        -  494  12004  10226
# 614     -       -  -  -        -  ...         -        -  146   3600   3189
# 615    11       -  -  -    8.538  ...  13500000    8.538  299   8480   7904
# 675    12       -  -  -        -  ...  14000000        -  518  16898  15522
#
#       T4     T5   S1   S2   S3
# 10   169    263   51   65   74
# 86   301    631   94  172  116
# 115  235    482   52  124  120
# 123  282    667   72  169  182
# 203  154    386   29   52  140
# 215  285    545   72   60  121
# 217    -      -    -    -    -
# 268  451    976   71  252  155
# 286  240    486   45  104   96
# 330  355  10277   64   48  123
# 357  236    483   54   64  170
# 400  192    384   45   68  139
# 401  237    534   73   88  132
# 410  298    565   63  115  170
# 490  230    410   61   92   91
# 496  258    677  129   87  154
# 503   95    249   27   56   26
# 560  172    325   44   65   85
# 597  277    560   46  100   91
# 614   88    181    5   26   38
# 615  198    550  101   46  127
# 675  370    790   71  146  190
#
# [22 rows x 22 columns]

# %%
# C1
data.loc[data['C1'] == '-']
# Out:
#        I1                                              I2    I3 P(IPO) P(H)  \
# 10   ADKU                      ADCARE HEALTH SYSTEMS, INC     -      -    -
# 86    BLT                        BLOUNT INTERNATIONAL INC     -      -    -
# 115  CELM                      CHINA ELECTRIC MOTOR, INC.  3621    4.5  6.5
# 123   CIL  China Intelligent Lighting & Electronics, Inc.  3640      3    5
# 203  ELMD                               Electromed, Inc.   3845      4    6
# 215  ESEA                                  EUROSEAS LTD.   4412      7    -
# 217  EURX                                    EURAND N.V.   2834     16   19
# 268   GSL                               GLOBAL SIGNAL INC     -     18    -
# 286   HPJ                   Highpower International, Inc.  3690   3.25    4
# 330   KFI                      KKR Financial Holdings LLC     -      -    -
# 357  LZEN                      Lizhan Environmental Corp   2200      4    6
# 400  NAUH     National American University Holdings, Inc.     -      -    -
# 401   NBY                   NovaBay Pharmaceuticals, Inc.  2834      4    6
# 410   NIV        NIVS IntelliMedia Technology Group, Inc.  3651    3.5    4
# 490   RCH                               CHINA CGAME, INC.     -    3.5    -
# 496  RGLS                       Regulus Therapeutics Inc.  2834      4   12
# 503  RNIN                             CREATIVE REALITIES,  7373      4    5
# 560  STRL                    STERLING CONSTRUCTION CO INC  1600     15    -
# 597  TRMM                          Access to Money, Inc.      -      -    -
# 614  TZOO                                   TRAVELZOO INC     -    3.5    -
# 615  TZYM                       Ocera Therapeutics, Inc.   2834      4   13
# 675  ZGNX                                   ZOGENIX, INC.  2834      4   14
#
#      P(L) P(1Day) C1 C2       C3  ...        C6       C7   T1     T2     T3  \
# 10      -       -  -  -        -  ...         -        -  332   7534   6747
# 86      -       -  -  -        -  ...         -        -  538  12732  11126
# 115   5.5       -  -  -        -  ...   5000000        -  351  10352   9296
# 123     4       -  -  -   59.261  ...   3350000   59.261  406  12065  11056
# 203     4       -  -  -   12.999  ...   1700000   12.999  224   6146   5551
# 215     -       -  -  -        -  ...   9602340        -  521  12812  11190
# 217    17       -  -  -  109.336  ...   7000000  109.336    -      -      -
# 268     -       -  -  -        -  ...   7000000        -  631  19479  17409
# 286     3       -  -  -   73.262  ...    525000   73.262  377  10731   9703
# 330     -       -  -  -        -  ...         -        -  246    527   9046
# 357     5       -  -  -   21.612  ...   2500000   21.612  373  10261   9189
# 400     -       -  -  -        -  ...         -        -  290   8454   7137
# 401     4       -  -  -    1.533  ...   5000000    1.533  382   9959   9215
# 410  3.25       -  -  -  101.048  ...    550000  101.048  451  12594  11210
# 490     -       -  -  -        -  ...    737000        -  322   9820   8893
# 496    10       -  -  -   13.789  ...  11250000   13.789  344  11091  10333
# 503     4       -  -  -  710.216  ...   4500000  710.216  199   5073   4395
# 560     -       -  -  -        -  ...   2021758        -  310   7195   6393
# 597     -       -  -  -        -  ...         -        -  494  12004  10226
# 614     -       -  -  -        -  ...         -        -  146   3600   3189
# 615    11       -  -  -    8.538  ...  13500000    8.538  299   8480   7904
# 675    12       -  -  -        -  ...  14000000        -  518  16898  15522
#
#       T4     T5   S1   S2   S3
# 10   169    263   51   65   74
# 86   301    631   94  172  116
# 115  235    482   52  124  120
# 123  282    667   72  169  182
# 203  154    386   29   52  140
# 215  285    545   72   60  121
# 217    -      -    -    -    -
# 268  451    976   71  252  155
# 286  240    486   45  104   96
# 330  355  10277   64   48  123
# 357  236    483   54   64  170
# 400  192    384   45   68  139
# 401  237    534   73   88  132
# 410  298    565   63  115  170
# 490  230    410   61   92   91
# 496  258    677  129   87  154
# 503   95    249   27   56   26
# 560  172    325   44   65   85
# 597  277    560   46  100   91
# 614   88    181    5   26   38
# 615  198    550  101   46  127
# 675  370    790   71  146  190
#
# [22 rows x 22 columns]

# %%
# C2
data.loc[data['C2'] == '-']
# Out:
#        I1                                              I2    I3 P(IPO) P(H)  \
# 10   ADKU                      ADCARE HEALTH SYSTEMS, INC     -      -    -
# 86    BLT                        BLOUNT INTERNATIONAL INC     -      -    -
# 115  CELM                      CHINA ELECTRIC MOTOR, INC.  3621    4.5  6.5
# 123   CIL  China Intelligent Lighting & Electronics, Inc.  3640      3    5
# 203  ELMD                               Electromed, Inc.   3845      4    6
# 215  ESEA                                  EUROSEAS LTD.   4412      7    -
# 217  EURX                                    EURAND N.V.   2834     16   19
# 268   GSL                               GLOBAL SIGNAL INC     -     18    -
# 286   HPJ                   Highpower International, Inc.  3690   3.25    4
# 330   KFI                      KKR Financial Holdings LLC     -      -    -
# 357  LZEN                      Lizhan Environmental Corp   2200      4    6
# 400  NAUH     National American University Holdings, Inc.     -      -    -
# 401   NBY                   NovaBay Pharmaceuticals, Inc.  2834      4    6
# 410   NIV        NIVS IntelliMedia Technology Group, Inc.  3651    3.5    4
# 490   RCH                               CHINA CGAME, INC.     -    3.5    -
# 496  RGLS                       Regulus Therapeutics Inc.  2834      4   12
# 503  RNIN                             CREATIVE REALITIES,  7373      4    5
# 560  STRL                    STERLING CONSTRUCTION CO INC  1600     15    -
# 597  TRMM                          Access to Money, Inc.      -      -    -
# 614  TZOO                                   TRAVELZOO INC     -    3.5    -
# 615  TZYM                       Ocera Therapeutics, Inc.   2834      4   13
# 675  ZGNX                                   ZOGENIX, INC.  2834      4   14
#
#      P(L) P(1Day) C1 C2       C3  ...        C6       C7   T1     T2     T3  \
# 10      -       -  -  -        -  ...         -        -  332   7534   6747
# 86      -       -  -  -        -  ...         -        -  538  12732  11126
# 115   5.5       -  -  -        -  ...   5000000        -  351  10352   9296
# 123     4       -  -  -   59.261  ...   3350000   59.261  406  12065  11056
# 203     4       -  -  -   12.999  ...   1700000   12.999  224   6146   5551
# 215     -       -  -  -        -  ...   9602340        -  521  12812  11190
# 217    17       -  -  -  109.336  ...   7000000  109.336    -      -      -
# 268     -       -  -  -        -  ...   7000000        -  631  19479  17409
# 286     3       -  -  -   73.262  ...    525000   73.262  377  10731   9703
# 330     -       -  -  -        -  ...         -        -  246    527   9046
# 357     5       -  -  -   21.612  ...   2500000   21.612  373  10261   9189
# 400     -       -  -  -        -  ...         -        -  290   8454   7137
# 401     4       -  -  -    1.533  ...   5000000    1.533  382   9959   9215
# 410  3.25       -  -  -  101.048  ...    550000  101.048  451  12594  11210
# 490     -       -  -  -        -  ...    737000        -  322   9820   8893
# 496    10       -  -  -   13.789  ...  11250000   13.789  344  11091  10333
# 503     4       -  -  -  710.216  ...   4500000  710.216  199   5073   4395
# 560     -       -  -  -        -  ...   2021758        -  310   7195   6393
# 597     -       -  -  -        -  ...         -        -  494  12004  10226
# 614     -       -  -  -        -  ...         -        -  146   3600   3189
# 615    11       -  -  -    8.538  ...  13500000    8.538  299   8480   7904
# 675    12       -  -  -        -  ...  14000000        -  518  16898  15522
#
#       T4     T5   S1   S2   S3
# 10   169    263   51   65   74
# 86   301    631   94  172  116
# 115  235    482   52  124  120
# 123  282    667   72  169  182
# 203  154    386   29   52  140
# 215  285    545   72   60  121
# 217    -      -    -    -    -
# 268  451    976   71  252  155
# 286  240    486   45  104   96
# 330  355  10277   64   48  123
# 357  236    483   54   64  170
# 400  192    384   45   68  139
# 401  237    534   73   88  132
# 410  298    565   63  115  170
# 490  230    410   61   92   91
# 496  258    677  129   87  154
# 503   95    249   27   56   26
# 560  172    325   44   65   85
# 597  277    560   46  100   91
# 614   88    181    5   26   38
# 615  198    550  101   46  127
# 675  370    790   71  146  190
#
# [22 rows x 22 columns]

# %%
# C3
data.loc[data['C3'] == '-']
# Out:
#        I1                                           I2    I3 P(IPO)  P(H)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC     -      -     -
# 43    ARP                 ARC DOCUMENT SOLUTIONS, INC.  7334     13    16
# 86    BLT                     BLOUNT INTERNATIONAL INC     -      -     -
# 113   CDM            China Century Dragon Media, Inc.   7311   5.25     7
# 115  CELM                   CHINA ELECTRIC MOTOR, INC.  3621    4.5   6.5
# 170    DG                          DOLLAR GENERAL CORP  5331     21    23
# 172  DIVX                                     DIVX INC  7371     16    14
# 177   DMD                             LEAF GROUP LTD.   7379     17    16
# 215  ESEA                               EUROSEAS LTD.   4412      7     -
# 243   FTD                              FTD Group, Inc.  7389     13    14
# 247  GASS                              StealthGas Inc.  4412   14.5    16
# 267   GSE                           GSE Holding, Inc.   3081      9    11
# 268   GSL                            GLOBAL SIGNAL INC     -     18     -
# 277  HEES                H&E Equipment Services, Inc.   7350     18    17
# 279  HERO                      HERCULES OFFSHORE, INC.  1381     20    20
# 310  IOMI                          INTERCELL USA, INC.  2834      7     9
# 330   KFI                   KKR Financial Holdings LLC     -      -     -
# 400  NAUH  National American University Holdings, Inc.     -      -     -
# 412  NLSN                        Nielsen Holdings plc   7374     23    22
# 416  NPTT                          NPTEST HOLDING CORP  3825     12     3
# 431  OCNF                            OCEANFREIGHT INC.  4412     19    21
# 454   PBH               Prestige Brands Holdings, Inc.  2834     16    16
# 475  PRTS                U.S. Auto Parts Network, Inc.  5531     10    12
# 490   RCH                            CHINA CGAME, INC.     -    3.5     -
# 544  SNTA               MADRIGAL PHARMACEUTICALS, INC.  2834     10    16
# 560  STRL                 STERLING CONSTRUCTION CO INC  1600     15     -
# 575   TEU                               BOX SHIPS INC.  4412     12    17
# 597  TRMM                       Access to Money, Inc.      -      -     -
# 599   TRW              ZF TRW AUTOMOTIVE HOLDINGS CORP  3714     28    30
# 614  TZOO                                TRAVELZOO INC     -    3.5     -
# 616  UACL           UNIVERSAL LOGISTICS HOLDINGS, INC.  4213     20    20
# 624   VCG                   WINDSTREAM HOLDINGS, INC.   4813     15    18
# 648  VTUS                  ASSEMBLY BIOSCIENCES, INC.   2834      6     7
# 655  WDAY                               Workday, Inc.   7372     28    26
# 672  XTXI                       ENLINK MIDSTREAM, INC.  1311   19.5  18.5
# 675  ZGNX                                ZOGENIX, INC.  2834      4    14
#
#      P(L)  P(1Day)   C1 C2 C3  ...        C6       C7   T1     T2     T3   T4  \
# 10      -        -    -  -  -  ...         -        -  332   7534   6747  169
# 43     14    13.75  112  1  -  ...  13350000        -  507  12468  11248  289
# 86      -        -    -  -  -  ...         -        -  538  12732  11126  301
# 113     6      5.3  270  0  -  ...   1200000        -  347  10344   9413  242
# 115   5.5        -    -  -  -  ...   5000000        -  351  10352   9296  235
# 170    21    22.73   85  1  -  ...  34100000  9495.25  808  21623  19603  498
# 172    12     18.7  140  1  -  ...   9100000   33.047  439  11526  10498  267
# 177    14  45.0372  173  1  -  ...   8900000        -  797  22667  20515  549
# 215     -        -    -  -  -  ...   9602340        -  521  12812  11190  285
# 243    12     13.6   78  1  -  ...  15407693   397.06  486  16280  13922  350
# 247    14     13.8   38  0  -  ...   8000000        -  386  10343   9280  233
# 267     8     11.5  214  0  -  ...   7000000        -  688  19260  17088  502
# 268     -        -    -  -  -  ...   7000000        -  631  19479  17409  451
# 277    15     23.1  109  1  -  ...  10937500   600.21  628  13202  11872  302
# 279    18        0  111  1  -  ...   9200000        -  494  12518  11207  297
# 310     7      6.8  121  1  -  ...   5000000        -  330   8777   7987  198
# 330     -        -    -  -  -  ...         -        -  246    527   9046  355
# 400     -        -    -  -  -  ...         -        -  290   8454   7137  192
# 412    20       25  237  1  -  ...  71428572     5126  832  28081  24205  617
# 416    11    11.49   92  1  -  ...  14600000  243.491  411  11737  10440  275
# 431    19   1158.6   16  1  -  ...  10750000        -  211   5205   4940  123
# 454    14    17.75  197  1  -  ...  28000000    87.92  625  15584  12784  369
# 475    10     11.9   99  1  -  ...  10000000        -  355   8667   7959  202
# 490     -        -    -  -  -  ...    737000        -  322   9820   8893  230
# 544    14     9.09   76  1  -  ...   5000000        -  364  10471   9584  229
# 560     -        -    -  -  -  ...   2021758        -  310   7195   6393  172
# 575    15       11   10  1  -  ...  11999999        -  208   6750   6382  144
# 597     -        -    -  -  -  ...         -        -  494  12004  10226  277
# 599    28     27.1   81  1  -  ...  24137931        -  646  19521  17558  437
# 614     -        -    -  -  -  ...         -        -  146   3600   3189   88
# 616    18     22.5   88  0  -  ...   5300000        -  487  11489  10017  267
# 624    16    15.31  307  1  -  ...  29375000        -  714  17324  15706  401
# 648     6     31.5  150  0  -  ...   2900000        -  235   7412   6551  156
# 655    24    48.69   43  1  -  ...  22750000        -  461  13520  12211  315
# 672  16.5  8.46667   75  0  -  ...   2306000        -  554  13739  12268  325
# 675    12        -    -  -  -  ...  14000000        -  518  16898  15522  370
#
#         T5   S1   S2   S3
# 10     263   51   65   74
# 43     701   79  140  142
# 86     631   94  172  116
# 113    492   73   97  136
# 115    482   52  124  120
# 170   1310  194  232  326
# 172    715   46   93  126
# 177   1200   95  165  291
# 215    545   72   60  121
# 243    674   48   73  112
# 247    364   49   58   94
# 267   1066  133  205  231
# 268    976   71  252  155
# 277    615   72  153  121
# 279    603   49  103  135
# 310    504   69   69  142
# 330  10277   64   48  123
# 400    384   45   68  139
# 412   1530  185  447  310
# 416    784   66  133  289
# 431    224   20   39   82
# 454    510   79  110   83
# 475    527   35   86  133
# 490    410   61   92   91
# 544    624   54   89  125
# 560    325   44   65   85
# 575    314   13   49   65
# 597    560   46  100   91
# 599   1154  114  389  286
# 614    181    5   26   38
# 616    493   48  130  104
# 624    903   91  167  168
# 648    353   33   77   67
# 655    722   57   70  129
# 672    843   65  139  174
# 675    790   71  146  190
#
# [36 rows x 22 columns]

# %%
# C4
data.loc[data['C4'] == '-']
# Out:
#        I1                                              I2    I3 P(IPO) P(H)  \
# 10   ADKU                      ADCARE HEALTH SYSTEMS, INC     -      -    -
# 86    BLT                        BLOUNT INTERNATIONAL INC     -      -    -
# 115  CELM                      CHINA ELECTRIC MOTOR, INC.  3621    4.5  6.5
# 123   CIL  China Intelligent Lighting & Electronics, Inc.  3640      3    5
# 203  ELMD                               Electromed, Inc.   3845      4    6
# 215  ESEA                                  EUROSEAS LTD.   4412      7    -
# 217  EURX                                    EURAND N.V.   2834     16   19
# 268   GSL                               GLOBAL SIGNAL INC     -     18    -
# 286   HPJ                   Highpower International, Inc.  3690   3.25    4
# 330   KFI                      KKR Financial Holdings LLC     -      -    -
# 357  LZEN                      Lizhan Environmental Corp   2200      4    6
# 400  NAUH     National American University Holdings, Inc.     -      -    -
# 401   NBY                   NovaBay Pharmaceuticals, Inc.  2834      4    6
# 410   NIV        NIVS IntelliMedia Technology Group, Inc.  3651    3.5    4
# 490   RCH                               CHINA CGAME, INC.     -    3.5    -
# 496  RGLS                       Regulus Therapeutics Inc.  2834      4   12
# 503  RNIN                             CREATIVE REALITIES,  7373      4    5
# 560  STRL                    STERLING CONSTRUCTION CO INC  1600     15    -
# 597  TRMM                          Access to Money, Inc.      -      -    -
# 614  TZOO                                   TRAVELZOO INC     -    3.5    -
# 615  TZYM                       Ocera Therapeutics, Inc.   2834      4   13
# 675  ZGNX                                   ZOGENIX, INC.  2834      4   14
#
#      P(L) P(1Day) C1 C2       C3  ...        C6       C7   T1     T2     T3  \
# 10      -       -  -  -        -  ...         -        -  332   7534   6747
# 86      -       -  -  -        -  ...         -        -  538  12732  11126
# 115   5.5       -  -  -        -  ...   5000000        -  351  10352   9296
# 123     4       -  -  -   59.261  ...   3350000   59.261  406  12065  11056
# 203     4       -  -  -   12.999  ...   1700000   12.999  224   6146   5551
# 215     -       -  -  -        -  ...   9602340        -  521  12812  11190
# 217    17       -  -  -  109.336  ...   7000000  109.336    -      -      -
# 268     -       -  -  -        -  ...   7000000        -  631  19479  17409
# 286     3       -  -  -   73.262  ...    525000   73.262  377  10731   9703
# 330     -       -  -  -        -  ...         -        -  246    527   9046
# 357     5       -  -  -   21.612  ...   2500000   21.612  373  10261   9189
# 400     -       -  -  -        -  ...         -        -  290   8454   7137
# 401     4       -  -  -    1.533  ...   5000000    1.533  382   9959   9215
# 410  3.25       -  -  -  101.048  ...    550000  101.048  451  12594  11210
# 490     -       -  -  -        -  ...    737000        -  322   9820   8893
# 496    10       -  -  -   13.789  ...  11250000   13.789  344  11091  10333
# 503     4       -  -  -  710.216  ...   4500000  710.216  199   5073   4395
# 560     -       -  -  -        -  ...   2021758        -  310   7195   6393
# 597     -       -  -  -        -  ...         -        -  494  12004  10226
# 614     -       -  -  -        -  ...         -        -  146   3600   3189
# 615    11       -  -  -    8.538  ...  13500000    8.538  299   8480   7904
# 675    12       -  -  -        -  ...  14000000        -  518  16898  15522
#
#       T4     T5   S1   S2   S3
# 10   169    263   51   65   74
# 86   301    631   94  172  116
# 115  235    482   52  124  120
# 123  282    667   72  169  182
# 203  154    386   29   52  140
# 215  285    545   72   60  121
# 217    -      -    -    -    -
# 268  451    976   71  252  155
# 286  240    486   45  104   96
# 330  355  10277   64   48  123
# 357  236    483   54   64  170
# 400  192    384   45   68  139
# 401  237    534   73   88  132
# 410  298    565   63  115  170
# 490  230    410   61   92   91
# 496  258    677  129   87  154
# 503   95    249   27   56   26
# 560  172    325   44   65   85
# 597  277    560   46  100   91
# 614   88    181    5   26   38
# 615  198    550  101   46  127
# 675  370    790   71  146  190
#
# [22 rows x 22 columns]

# %%
# C5
data.loc[data['C5'] == '-']
# Out:
#        I1                                           I2 I3 P(IPO) P(H) P(L)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC  -      -    -    -
# 86    BLT                     BLOUNT INTERNATIONAL INC  -      -    -    -
# 330   KFI                   KKR Financial Holdings LLC  -      -    -    -
# 400  NAUH  National American University Holdings, Inc.  -      -    -    -
# 597  TRMM                       Access to Money, Inc.   -      -    -    -
# 614  TZOO                                TRAVELZOO INC  -    3.5    -    -
#
#     P(1Day) C1 C2 C3  ... C6 C7   T1     T2     T3   T4     T5  S1   S2   S3
# 10        -  -  -  -  ...  -  -  332   7534   6747  169    263  51   65   74
# 86        -  -  -  -  ...  -  -  538  12732  11126  301    631  94  172  116
# 330       -  -  -  -  ...  -  -  246    527   9046  355  10277  64   48  123
# 400       -  -  -  -  ...  -  -  290   8454   7137  192    384  45   68  139
# 597       -  -  -  -  ...  -  -  494  12004  10226  277    560  46  100   91
# 614       -  -  -  -  ...  -  -  146   3600   3189   88    181   5   26   38
#
# [6 rows x 22 columns]

# %%
# C6
data.loc[data['C6'] == '-']
# Out:
#        I1                                           I2 I3 P(IPO) P(H) P(L)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC  -      -    -    -
# 86    BLT                     BLOUNT INTERNATIONAL INC  -      -    -    -
# 330   KFI                   KKR Financial Holdings LLC  -      -    -    -
# 400  NAUH  National American University Holdings, Inc.  -      -    -    -
# 597  TRMM                       Access to Money, Inc.   -      -    -    -
# 614  TZOO                                TRAVELZOO INC  -    3.5    -    -
#
#     P(1Day) C1 C2 C3  ... C6 C7   T1     T2     T3   T4     T5  S1   S2   S3
# 10        -  -  -  -  ...  -  -  332   7534   6747  169    263  51   65   74
# 86        -  -  -  -  ...  -  -  538  12732  11126  301    631  94  172  116
# 330       -  -  -  -  ...  -  -  246    527   9046  355  10277  64   48  123
# 400       -  -  -  -  ...  -  -  290   8454   7137  192    384  45   68  139
# 597       -  -  -  -  ...  -  -  494  12004  10226  277    560  46  100   91
# 614       -  -  -  -  ...  -  -  146   3600   3189   88    181   5   26   38
#
# [6 rows x 22 columns]

# %%
# C7
data.loc[data['C7'] == '-']
# Out:
#        I1                            I2    I3 P(IPO)  P(H)  P(L)  P(1Day)  \
# 7    ACRX    ACELRX PHARMACEUTICALS INC  2834      5    14    12     4.55
# 10   ADKU    ADCARE HEALTH SYSTEMS, INC     -      -     -     -        -
# 20   ALIM         ALIMERA SCIENCES INC   2834     11    17    15       11
# 43    ARP  ARC DOCUMENT SOLUTIONS, INC.  7334     13    16    14    13.75
# 45   ARTE             ARTES MEDICAL INC  2834      6    14    12     7.67
# ..    ...                           ...   ...    ...   ...   ...      ...
# 648  VTUS   ASSEMBLY BIOSCIENCES, INC.   2834      6     7     6     31.5
# 655  WDAY                Workday, Inc.   7372     28    26    24    48.69
# 671  XTNT                     XTENT INC  3841     16    18    16    16.48
# 672  XTXI        ENLINK MIDSTREAM, INC.  1311   19.5  18.5  16.5  8.46667
# 675  ZGNX                 ZOGENIX, INC.  2834      4    14    12        -
#
#       C1 C2    C3  ...        C6 C7   T1     T2     T3   T4   T5  S1   S2   S3
# 7     91  0 -0.74  ...   8000000  -  334  11226  10056  276   -1  55  120  122
# 10     -  -     -  ...         -  -  332   7534   6747  169  263  51   65   74
# 20   174  1 -1.43  ...   6550000  -  473  13801  12500  296  768  66  136  182
# 43   112  1     -  ...  13350000  -  507  12468  11248  289  701  79  140  142
# 45   222  1 -1.42  ...   4600000  -  280   8296   7337  178  514  37   77  106
# ..   ... ..   ...  ...       ... ..  ...    ...    ...  ...  ...  ..  ...  ...
# 648  150  0     -  ...   2900000  -  235   7412   6551  156  353  33   77   67
# 655   43  1     -  ...  22750000  -  461  13520  12211  315  722  57   70  129
# 671  178  1  -1.6  ...   4700000  -  275   6542   6008  146  357  41   67  111
# 672   75  0     -  ...   2306000  -  554  13739  12268  325  843  65  139  174
# 675    -  -     -  ...  14000000  -  518  16898  15522  370  790  71  146  190
#
# [72 rows x 22 columns]

# %%
# T1 --> T5
data.loc[data['T1'] == '-']
# Out:
#        I1            I2    I3 P(IPO) P(H) P(L) P(1Day) C1 C2       C3  ...  \
# 217  EURX  EURAND N.V.   2834     16   19   17       -  -  -  109.336  ...
#
#           C6       C7 T1 T2 T3 T4 T5 S1 S2 S3
# 217  7000000  109.336  -  -  -  -  -  -  -  -
#
# [1 rows x 22 columns]

# %%
# S1 --> S3
data.loc[data['S3'] == '-']
# Out:
#        I1            I2    I3 P(IPO) P(H) P(L) P(1Day) C1 C2       C3  ...  \
# 217  EURX  EURAND N.V.   2834     16   19   17       -  -  -  109.336  ...
#
#           C6       C7 T1 T2 T3 T4 T5 S1 S2 S3
# 217  7000000  109.336  -  -  -  -  -  -  -  -
#
# [1 rows x 22 columns]

# %%
# T5 --> -1 
data.loc[data['T5'] == -1]
# Out:
#      I1                          I2    I3 P(IPO) P(H) P(L) P(1Day)  C1 C2  \
# 7  ACRX  ACELRX PHARMACEUTICALS INC  2834      5   14   12    4.55  91  0
#
#      C3  ...       C6 C7   T1     T2     T3   T4  T5  S1   S2   S3
# 7 -0.74  ...  8000000  -  334  11226  10056  276  -1  55  120  122
#
# [1 rows x 22 columns]

# %%
# S1 --> -1 
data.loc[data['S1'] == -1]
# Out:
#        I1            I2    I3 P(IPO) P(H) P(L) P(1Day)   C1 C2    C3  ...  \
# 134  COGT  Cogent, inc.  7373     12   12   10   17.98  133  1  0.14  ...
#
#            C6      C7   T1     T2    T3   T4   T5  S1  S2   S3
# 134  18000000  32.179  419  10764  9856  259  643  -1  97  134
#
# [1 rows x 22 columns]

# %%
# C3 --> -1 
data.loc[data['C3'] == -1]
# Out:
#       I1                            I2    I3 P(IPO) P(H) P(L) P(1Day)  C1 C2  \
# 47  ASPV  Aspreva Pharmaceuticals CORP  2834     11   15   13   14.79  39  1
#
#     C3  ...       C6 C7   T1    T2    T3   T4   T5  S1  S2  S3
# 47  -1  ...  7200000  -  223  5079  4700  104  292  29  60  76
#
# [1 rows x 22 columns]

# %%
# P(H) --> 0 
data.loc[data['P(H)'] == 0]
# Out:
#        I1                      I2    I3 P(IPO) P(H) P(L) P(1Day)   C1 C2   C3  \
# 332  KIPS  Kips Bay Medical, Inc.  3841      8    0    8    7.93  309  0 -0.7
#
#      ...       C6     C7   T1    T2    T3   T4   T5  S1   S2   S3
# 332  ...  2062500  0.223  341  9314  8647  218  519  55  119  102
#
# [1 rows x 22 columns]

# %%
# P(1Day) --> 0 
data.loc[data['P(1Day)'] == 0]
# Out:
#        I1                       I2    I3 P(IPO) P(H) P(L) P(1Day)   C1 C2  \
# 9     ACW            ACCURIDE CORP  3714      9   19   17       0  106  1
# 266  GSAT        Globalstar, Inc.   4899     17   18   16       0  108  1
# 279  HERO  HERCULES OFFSHORE, INC.  1381     20   20   18       0  111  1
# 364  MATH                SAJAN INC  3674      6    8    6       0   85  0
#
#        C3  ...        C6       C7   T1     T2     T3   T4   T5  S1   S2   S3
# 9    1.49  ...  11000000  494.008  385   9134   8107  198  459  81   90  147
# 266  0.23  ...   7500000  127.147  759  18196  16262  397  959  85  228  173
# 279     -  ...   9200000        -  494  12518  11207  297  603  49  103  135
# 364 -0.95  ...   4000000      130  235   5674   5085  132  284  27   66   63
#
# [4 rows x 22 columns]

# %%
# C2 --> 0 
data.loc[data['C2'] == 0]
# Out:
#        I1                               I2    I3 P(IPO)  P(H)  P(L)  P(1Day)  \
# 1    ABPI  ACCENTIA BIOPHARMACEUTICALS INC  2834      8    10     8     7.25
# 7    ACRX       ACELRX PHARMACEUTICALS INC  2834      5    14    12     4.55
# 32   ANGO                ANGIODYNAMICS INC  3841     11    14    12     12.5
# 57   AVRX       AVALON PHARMACEUTICALS INC  2834   10.5    12    10     9.49
# 72   BDAY           CELEBRATE EXPRESS, INC  5961   15.5    15    13     16.7
# ..    ...                              ...   ...    ...   ...   ...      ...
# 664  WSSI            VISUAL SCIENCES, INC.  7372    8.5     9     8     9.04
# 667  XCYT    Cyclacel Pharmaceuticals, Inc  2834      8    15    13    511.7
# 672  XTXI           ENLINK MIDSTREAM, INC.  1311   19.5  18.5  16.5  8.46667
# 674   ZBB                     EnSync, Inc.  4911      6   6.5   5.5       29
# 679  ZSTN       ZST Digital Networks, Inc.  3663      8   8.5   7.5     7.52
#
#       C1 C2    C3  ...       C6       C7   T1     T2     T3   T4    T5  S1  \
# 1    259  0 -1.62  ...  2400000   25.936  791  21792  19585  510  1120  71
# 7     91  0 -0.74  ...  8000000        -  334  11226  10056  276    -1  55
# 32    83  0  0.13  ...  1950000   38.434  329   7154   6296  175   384  47
# 57   149  0 -1.63  ...  2750000      1.9  270   6360   5780  146   356  63
# 72    96  0 -0.34  ...  3200000   37.811  298   7231   6423  196   270  30
# ..   ... ..   ...  ...      ...      ...  ...    ...    ...  ...   ...  ..
# 664  124  0 -0.86  ...  5000000    16.36  263   6650   6002  165   390  32
# 667  158  0 -12.4  ...  4200000     0.17  210   5099   4561  125   322  18
# 672   75  0     -  ...  2306000        -  554  13739  12268  325   843  65
# 674  234  0  -0.6  ...  3333333  540.399  335   9278   8067  223   394  38
# 679  112  0   0.6  ...  3125000   55.431  335   9067   8066  217   435  38
#
#       S2   S3
# 1    242  237
# 7    120  122
# 32    47   94
# 57    38   72
# 72    48   97
# ..   ...  ...
# 664   66   75
# 667   44   67
# 672  139  174
# 674   60   59
# 679   82   90
#
# [93 rows x 22 columns]

# %%
# C3 --> 0 
data.loc[data['C3'] == 0]
# Out:
#        I1                      I2    I3 P(IPO) P(H) P(L) P(1Day)   C1 C2 C3  \
# 36   APKT         ACME PACKET INC  3576    9.5  7.5  6.5   15.91  133  1  0
# 346  LMAT  LEMAITRE VASCULAR INC   3841      7   10    8     6.2  177  1  0
# 383    MM   Millennial Media Inc.  7311     13   11    9      25   84  1  0
# 628  VITC      Vitacost.com, Inc.  7389     12   13   11   12.05  827  0  0
# 645   VSE     VERASUN ENERGY CORP  2860     23   22   21      30   76  1  0
#
#      ...        C6       C7   T1     T2     T3   T4   T5  S1   S2   S3
# 36   ...  11474528    36.12  547  14728  13418  345  841  60  149  176
# 346  ...   5500000   30.727  500  11490  10438  277  556  61  151  149
# 383  ...  10200000  103.678  560  16053  14755  395  818  70  108  145
# 628  ...  11000000  143.602  380   9286   8021  226  458  54   45  118
# 645  ...  18250000  236.359  397  10947   9388  244  398  26   74   92
#
# [5 rows x 22 columns]

# %%
# T2 --> 0 
data.loc[data['T2'] == 0]
# Out:
#       I1                       I2    I3 P(IPO) P(H) P(L) P(1Day)   C1 C2  \
# 125  CLD  CLOUD PEAK ENERGY INC.   1221     15   18   16   14.84  100  1
# 199  EDG        Edgen Group Inc.   5150     11   16   14     9.5  120  1
#
#        C3  ...        C6       C7   T1 T2     T3   T4    T5   S1   S2   S3
# 125     2  ...  30600000  1239.71  656  0  18173  486  1135   77  229  219
# 199 -0.59  ...  15000000  911.612  619  0  19153  474  1108  104  224  253
#
# [2 rows x 22 columns]

# %%
# T3 --> 0 
data.loc[data['T3'] == 0]
# Out:
#        I1                     I2    I3 P(IPO) P(H) P(L) P(1Day)  C1 C2    C3  \
# 27   AMIS      AMIS HOLDINGS INC  3674     20   20   18    20.1  40  1 -0.41
# 256  GMAN  Gordmans Stores, Inc.  5600     11   15   13   11.03  97  1  0.13
# 484  QNST        QUINSTREET, INC  7389     15   19   17      15  84  1  0.38
#
#      ...        C6       C7   T1     T2 T3   T4   T5  S1   S2   S3
# 27   ...  30000000  345.322  527  15006  0  334  809  46  181  167
# 256  ...   5357143  438.135  385  12828  0  286  591  79   89  181
# 484  ...  10000000  260.527  539  16189  0  387  742  59  160  170
#
# [3 rows x 22 columns]

# %%
# T4 --> 0 
data.loc[data['T4'] == 0]
# Out:
#        I1                                I2    I3 P(IPO) P(H) P(L) P(1Day)  \
# 250   GGS  Global Geophysical Services Inc   1382     12   17   15      12
# 478  PSPT              PeopleSupport, Inc.   7389      7   12   10     6.5
#
#       C1 C2    C3  ...       C6       C7   T1     T2     T3 T4   T5  S1   S2  \
# 250  188  1  0.05  ...  7500000  312.796  473  12699  11422  0  693  84  112
# 478  144  0  0.67  ...  6818182   30.013  483  12658  11451  0  800  67  161
#
#       S3
# 250  123
# 478  152
#
# [2 rows x 22 columns]

# %%
# P(H) < P(L)
data.loc[data['P(H)'] < data['P(L)']]
# Out:
#        I1                      I2    I3 P(IPO) P(H) P(L) P(1Day)   C1 C2   C3  \
# 332  KIPS  Kips Bay Medical, Inc.  3841      8    0    8    7.93  309  0 -0.7
# 416  NPTT     NPTEST HOLDING CORP  3825     12    3   11   11.49   92  1    -
#
#      ...        C6       C7   T1     T2     T3   T4   T5  S1   S2   S3
# 332  ...   2062500    0.223  341   9314   8647  218  519  55  119  102
# 416  ...  14600000  243.491  411  11737  10440  275  784  66  133  289
#
# [2 rows x 22 columns]

# %% [markdown]
# # PLAN
# - In every stage make e.g. 5 different ways of doing that --> store that in a seperate notebook
# - Connect pipelines in different ways (most probable)
# - In the end have multiple notebooks/files to be tested

# %%
# if you want to display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 30)

# %% [markdown]
# # Data Cleaning
# 1. Finding Null/wrong values
#     - '-' --> some
#     - dtype --> All
#     - -1 --> T5, S1
#     - 0 (P(1Day)), T2, T3, T4
#     - I3 industry type
#     - P(H) < P(L)
#     - C2 (how to fill that)
# 2. Make assumptions to why this happen and how to resolve/imputate it
#     STEP1: Dashes (P(H), P(L)) --> those that have P(IPO) average distance
#     * STEP2: find out what is the industry classifier (I3) --> that have dashes
#     STEP3: infer average distance for P(1Day) --> cannot be more than 3x price --> mean distance
#     STEP4: C1 --> C7 --> those that have information give best possible guess to fill in the dash (e.g. average distance)
#     STEP5: ASSUMTION -1 means none
#     STEP6: appropriate guess for 0
#     STEP6: data[data['P(H)'] < data['P(L)']] --> replace with best guess/switch
#     STEP7: Dashes --> replace all dashes with NaN
#
#     STEP8: replace nan's with imputation method: Median, mode, mean

# %%
# exclude bbfill and fffill

# %%
# replace dashes, 0 and -1 with nan
data = data.replace('-',np.nan)
# column by column 
data = data.replace(0,np.nan)
# column by column 
data = data.replace(-1,np.nan)

# %%
# SIC --> I3 --> what the industry is

# %%
# difference between mean and median
print(data['P(IPO)'].mean())
print(data['P(IPO)'].median())
# Out:
# 13.837666174298375
# 13.5

# %%
# Assumption P(H) is much more likely to be larger than P(IPO)
data[(data['P(H)']>data['P(IPO)'])].head()
# Out:
#      I1                               I2    I3  P(IPO)  P(H)  P(L)  P(1Day)  \
# 1  ABPI  ACCENTIA BIOPHARMACEUTICALS INC  2834     8.0  10.0   8.0     7.25
# 2  ACAD       ACADIA PHARMACEUTICALS INC  2834     7.0  14.0  12.0     6.70
# 3  ACHN    ACHILLION PHARMACEUTICALS INC  2834    11.5  16.0  14.0    12.39
# 5  ACOM               Ancestry.com Inc.   7379    13.5  14.5  12.5    14.20
# 6  ACOR          ACORDA THERAPEUTICS INC  2836     6.0  13.0  11.0     6.72
#
#       C1   C2    C3  ...         C6       C7     T1       T2       T3     T4  \
# 1  259.0  NaN -1.62  ...  2400000.0   25.936  791.0  21792.0  19585.0  510.0
# 2   90.0  1.0 -1.24  ...  5000000.0    7.378  201.0   5262.0   4785.0  128.0
# 3  209.0  1.0 -0.91  ...  4500000.0    8.526  328.0   8259.0   7574.0  177.0
# 5   94.0  1.0  0.06  ...  7407407.0  197.591  510.0  17999.0  13934.0  328.0
# 6  128.0  1.0 -1.87  ...  5500000.0    5.146  495.0  15758.0  13953.0  379.0
#
#        T5    S1     S2     S3
# 1  1120.0  71.0  242.0  237.0
# 2   325.0  61.0   33.0   60.0
# 3   509.0  80.0   59.0  110.0
# 5   815.0  62.0   96.0  181.0
# 6   698.0  82.0  106.0  135.0
#
# [5 rows x 22 columns]

# %%
# standard deviation 
data[['P(IPO)','P(H)']].std()
# Out:
# P(IPO)    6.053731
# P(H)      6.631436
# dtype: float64

# %%
# median distance of P(IPO) and P(H)
# we take median because we want to avoid the extreme values if we take the mean 
IPO_H_dist = data['P(H)'] - data['P(IPO)'] 
IPO_H_dist.median()
# Out:
# 1.0

# %%
# median distance of P(IPO) and P(L)
IPO_L_dist = data['P(IPO)'] - data['P(L)']
IPO_L_dist.median()
# Out:
# 0.5

# %%
# median distance of P(H) and P(L)
H_L_dist = data['P(H)'] - data['P(L)'] 
H_L_dist.median()
# Out:
# 2.0

# %%
# ASSUMPTION P(1Day) usually larger 
data[(data['P(1Day)']>data['P(IPO)'])].head()
# Out:
#      I1                                  I2    I3  P(IPO)  P(H)  P(L)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674    10.0   9.5   8.5
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834    11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492    21.0  21.0  19.0
# 5  ACOM                  Ancestry.com Inc.   7379    13.5  14.5  12.5
# 6  ACOR             ACORDA THERAPEUTICS INC  2836     6.0  13.0  11.0
#
#      P(1Day)     C1   C2    C3  ...       T2       T3     T4     T5    S1  \
# 0  11.870000  122.0  1.0  3.43  ...  12719.0  11560.0  301.0  690.0  62.0
# 3  12.390000  209.0  1.0 -0.91  ...   8259.0   7574.0  177.0  509.0  80.0
# 4  56.599998   80.0  1.0  0.07  ...  14830.0  13176.0  336.0  720.0  67.0
# 5  14.200000   94.0  1.0  0.06  ...  17999.0  13934.0  328.0  815.0  62.0
# 6   6.720000  128.0  1.0 -1.87  ...  15758.0  13953.0  379.0  698.0  82.0
#
#       S2     S3  IPO/H_dist  IPO/L_dist  H/L_dist
# 0  117.0  139.0        -0.5         1.5       1.0
# 3   59.0  110.0         4.5        -2.5       2.0
# 4  149.0  167.0         0.0         2.0       2.0
# 5   96.0  181.0         1.0         1.0       2.0
# 6  106.0  135.0         7.0        -5.0       2.0
#
# [5 rows x 25 columns]

# %%
# median distance between P(1Day) and P(IPO)
p1day_diff_pio = data['P(1Day)'] - data['P(IPO)'] 
p1day_diff_pio.median()
# Out:
# 0.9399999046325496

# %% [markdown]
# # I3

# %%
data.loc[data['I2'] == 'ADCARE HEALTH SYSTEMS, INC', 'I3'] = 8099
data.loc[data['I2'] == 'BLOUNT INTERNATIONAL INC', 'I3'] = 1600
data.loc[data['I2'] == 'GLOBAL SIGNAL INC', 'I3'] = 3577
data.loc[data['I2'] == 'KKR Financial Holdings LLC', 'I3'] = 7011
data.loc[data['I2'] == 'National American University Holdings, Inc.', 'I3'] = 8221
data.loc[data['I2'] == 'CHINA CGAME, INC.', 'I3'] = 1600
data.loc[data['I2'] == 'Access to Money, Inc.', 'I3'] = 7011
data.loc[data['I2'] == 'TRAVELZOO INC', 'I3'] = 7374

# %% [markdown]
# # P(H)

# %%
data.loc[data['I2'] == 'EUROSEAS LTD.', 'P(H)'] = 8
data.loc[data['I2'] == 'GLOBAL SIGNAL INC', 'P(H)'] = 19
data.loc[data['I2'] == 'CHINA CGAME, INC.', 'P(H)'] = 4.5
data.loc[data['I2'] == 'STERLING CONSTRUCTION CO INC', 'P(H)'] = 16
data.loc[data['I2'] == 'TRAVELZOO INC', 'P(H)'] = 4.5

# %% [markdown]
# # P(L)

# %%
data.loc[data['I2'] == 'EUROSEAS LTD.', 'P(L)'] = 6
data.loc[data['I2'] == 'GLOBAL SIGNAL INC', 'P(L)'] = 17
data.loc[data['I2'] == 'CHINA CGAME, INC.', 'P(L)'] = 2.5
data.loc[data['I2'] == 'STERLING CONSTRUCTION CO INC', 'P(L)'] = 14
data.loc[data['I2'] == 'TRAVELZOO INC', 'P(L)'] = 2.5

# %% [markdown]
# # P(1Day)

# %%
data.loc[data['I2'] == 'CHINA ELECTRIC MOTOR, INC.', 'P(1Day)'] = 5.39
data.loc[data['I2'] == 'China Intelligent Lighting & Electronics, Inc.', 'P(1Day)'] = 3.89
data.loc[data['I2'] == 'Electromed, Inc.', 'P(1Day)'] = 4.89
data.loc[data['I2'] == 'EUROSEAS LTD.', 'P(1Day)'] = 7.89
data.loc[data['I2'] == 'EURAND N.V.', 'P(1Day)'] = 16.89
data.loc[data['I2'] == 'GLOBAL SIGNAL INC', 'P(1Day)'] = 18.89
data.loc[data['I2'] == 'Highpower International, Inc.', 'P(1Day)'] = 4.14
data.loc[data['I2'] == 'Lizhan Environmental Corp', 'P(1Day)'] = 4.89
data.loc[data['I2'] == 'NovaBay Pharmaceuticals, Inc.', 'P(1Day)'] = 4.89
data.loc[data['I2'] == 'NIVS IntelliMedia Technology Group, Inc.', 'P(1Day)'] = 4.39
data.loc[data['I2'] == 'CHINA CGAME, INC.', 'P(1Day)'] = 4.39
data.loc[data['I2'] == 'Regulus Therapeutics Inc.', 'P(1Day)'] = 4.89
data.loc[data['I2'] == 'CREATIVE REALITIES,', 'P(1Day)'] = 4.89
data.loc[data['I2'] == 'STERLING CONSTRUCTION CO INC,', 'P(1Day)'] = 15.89
data.loc[data['I2'] == 'TRAVELZOO INC', 'P(1Day)'] = 4.39
data.loc[data['I2'] == 'Ocera Therapeutics, Inc.', 'P(1Day)'] = 4.89
data.loc[data['I2'] == 'ZOGENIX, INC.', 'P(1Day)'] = 4.89

# %% [markdown]
# ### Replacing C2

# %%
# MOST OF THE COMPANIES THAT HAD THE UNDERWRITER RANKING ABOVE 8 stock price incerased on day 1 PRICE
better_writer_stock = data[(data['P(1Day)']>data['P(IPO)']) & (data['C2']==1)]
better_writer_stock.head()
# Out:
#      I1                                  I2    I3  P(IPO)  P(H)  P(L)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674    10.0   9.5   8.5
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834    11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492    21.0  21.0  19.0
# 5  ACOM                  Ancestry.com Inc.   7379    13.5  14.5  12.5
# 6  ACOR             ACORDA THERAPEUTICS INC  2836     6.0  13.0  11.0
#
#      P(1Day)     C1   C2    C3  ...          C6       C7     T1       T2  \
# 0  11.870000  122.0  1.0  3.43  ...  10600000.0   51.345  470.0  12719.0
# 3  12.390000  209.0  1.0 -0.91  ...   4500000.0    8.526  328.0   8259.0
# 4  56.599998   80.0  1.0  0.07  ...   8250000.0  632.298  572.0  14830.0
# 5  14.200000   94.0  1.0  0.06  ...   7407407.0  197.591  510.0  17999.0
# 6   6.720000  128.0  1.0 -1.87  ...   5500000.0    5.146  495.0  15758.0
#
#         T3     T4     T5    S1     S2     S3
# 0  11560.0  301.0  690.0  62.0  117.0  139.0
# 3   7574.0  177.0  509.0  80.0   59.0  110.0
# 4  13176.0  336.0  720.0  67.0  149.0  167.0
# 5  13934.0  328.0  815.0  62.0   96.0  181.0
# 6  13953.0  379.0  698.0  82.0  106.0  135.0
#
# [5 rows x 22 columns]

# %%
# Fill dashes where we have info on P(1Day) and P(IPO) and unknown C2
# If P(1Day) higher than P(IPO), C2 = 1, otherwise 0
data.loc[data['I1'] == 'CELM', 'C2'] = 
data.loc[data['I1'] == 'CELM', 'C2'] = 
data.loc[data['I1'] == 'ELMD', 'C2'] = 
data.loc[data['I1'] == 'ESEA', 'C2'] = 
data.loc[data['I1'] == 'EURX', 'C2'] = 
data.loc[data['I1'] == 'GSL', 'C2'] = 
data.loc[data['I1'] == 'HPJ', 'C2'] = 
data.loc[data['I1'] == 'LZEN', 'C2'] = 
data.loc[data['I1'] == 'NBY', 'C2'] = 
data.loc[data['I1'] == 'NIV', 'C2'] = 
data.loc[data['I1'] == 'RCH', 'C2'] = 
data.loc[data['I1'] == 'RGLS', 'C2'] = 
data.loc[data['I1'] == 'RNIN', 'C2'] = 
data.loc[data['I1'] == 'STRL', 'C2'] = 
data.loc[data['I1'] == 'TZOO', 'C2'] = 
data.loc[data['I1'] == 'TZYM', 'C2'] = 
data.loc[data['I1'] == 'ZGNX', 'C2'] =
# Out:
#        I1                          I2    I3  P(IPO)  P(H)  P(L)  P(1Day)  C1  \
# 115  CELM  CHINA ELECTRIC MOTOR, INC.  3621     4.5   6.5   5.5      NaN NaN
#
#       C2  C3  ...         C6  C7     T1       T2      T3     T4     T5    S1  \
# 115  0.0 NaN  ...  5000000.0 NaN  351.0  10352.0  9296.0  235.0  482.0  52.0
#
#         S2     S3
# 115  124.0  120.0
#
# [1 rows x 22 columns]

# %%
#data.loc[((data['P(1Day)'] > data['P(IPO)']) & (data['C2']==np.nan)),'C2']=1

# %% [markdown]
# # I3 dashes and zereos
# - Dolby Laboratories, Inc.	 3672.0
# - DTS, INC.	3672.0
# - RealD Inc.	 3672.0
# - UNIVERSAL POWER GROUP	3674.0
# - CHINA CGAME, INC.	0.0 --> Arhitecture --> 1600
# - Access to Money, Inc.	0.0 --> 7011.0
# - BLOUNT INTERNATIONAL INC	 1600
# - GLOBAL SIGNAL INC	0.0 --> 3577.0
# - National American University Holdings, Inc.	0.0 --> 8221.0
# - ADCARE HEALTH SYSTEMS, INC	 8099
# - TRAVELZOO INC	0.0 --> 7374.0
# - KKR Financial Holdings LLC	 7011.0

# %% [markdown]
# # Imputation
# ### Decide on the order + different pipelines
# - replace dashes (-), 0, -1, P(H) < P(L) with NaN
# - number and % of missing data<br>
#     - percent_missing = df.isnull().sum() * 100 / len(df)<br>
#     missing_value_df = pd.DataFrame({'column_name': df.columns,'percent_missing': percent_missing})
# - make them a seperate columns
#
# - correct dtype<br>
# - column calculation
#     - the problem probably was because we made calculations for new columns before imputing (so first impute then calculate new columns)
#
# Methods:
# 3. median
# 4. mean
# 5. mode
# 6. Treating missing as seperate value (new column/binary value)
# 7. Infer Baysen/classification tree's
#     - http://nadbordrozd.github.io/blog/2017/03/05/missing-data-imputation-with-bayesian-networks/
#     - https://pypi.org/project/predictive_imputer/
#     - https://www.analyticsvidhya.com/blog/2016/03/tutorial-powerful-packages-imputing-missing-values/
#     - https://xgboost.readthedocs.io/en/latest/
#     -
# 8. Binning??

# %%
# imputing with mean 
cols = ['I3', 'P(IPO)', 'P(H)', 'P(L)', 'P(1Day)', 'C1', 'C2', 'C3',
       'C4', 'C5', 'C6', 'C7', 'T1', 'T2', 'T3', 'T4', 'T5', 'S1', 'S2', 'S3']
data[cols]=data[cols].fillna(data.mean().iloc[0])

# %%
# with median
cols = ['I3', 'P(IPO)', 'P(H)', 'P(L)', 'P(1Day)', 'C1', 'C2', 'C3',
       'C4', 'C5', 'C6', 'C7', 'T1', 'T2', 'T3', 'T4', 'T5', 'S1', 'S2', 'S3']
data[cols]=data[cols].fillna(data.median().iloc[0])

# %%
# with mode
cols = ['I3', 'P(IPO)', 'P(H)', 'P(L)', 'P(1Day)', 'C1', 'C2', 'C3',
       'C4', 'C5', 'C6', 'C7', 'T1', 'T2', 'T3', 'T4', 'T5', 'S1', 'S2', 'S3']
data[cols]=data[cols].fillna(data.mode().iloc[0])

# %%
# I3 --> binning 
# tech/non-tech, other

# %%
# knn imputer
from sklearn.impute import KNNImputer
#I3 was removed 
cols = ['P(IPO)', 'P(H)', 'P(L)', 'P(1Day)', 'C1', 'C2', 'C3',
       'C4', 'C5', 'C6', 'C7', 'T1', 'T2', 'T3', 'T4', 'T5', 'S1', 'S2', 'S3']

imputer = KNNImputer(n_neighbors=2)
data_filled = imputer.fit_transform(data[cols])
data_filled_df = pd.DataFrame(data_filled)
data_filled_df.head()
data_filled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 19 columns):
# 0     682 non-null float64
# 1     682 non-null float64
# 2     682 non-null float64
# 3     682 non-null float64
# 4     682 non-null float64
# 5     682 non-null float64
# 6     682 non-null float64
# 7     682 non-null float64
# 8     682 non-null float64
# 9     682 non-null float64
# 10    682 non-null float64
# 11    682 non-null float64
# 12    682 non-null float64
# 13    682 non-null float64
# 14    682 non-null float64
# 15    682 non-null float64
# 16    682 non-null float64
# 17    682 non-null float64
# 18    682 non-null float64
# dtypes: float64(19)
# memory usage: 101.4 KB

# %% [markdown]
# # Conversion C2

# %%
# C2 to binary (integers)
data['C2'] = data['C2'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 22 columns):
# I1         682 non-null object
# I2         682 non-null object
# I3         682 non-null object
# P(IPO)     682 non-null float64
# P(H)       682 non-null float64
# P(L)       682 non-null float64
# P(1Day)    682 non-null float64
# C1         682 non-null float64
# C2         682 non-null int64
# C3         682 non-null float64
# C4         682 non-null float64
# C5         682 non-null float64
# C6         682 non-null float64
# C7         682 non-null float64
# T1         682 non-null float64
# T2         682 non-null float64
# T3         682 non-null float64
# T4         682 non-null float64
# T5         682 non-null float64
# S1         682 non-null float64
# S2         682 non-null float64
# S3         682 non-null float64
# dtypes: float64(18), int64(1), object(3)
# memory usage: 117.3+ KB

# %% [markdown]
# ## Calculations

# %%
# P(mid) calculation and add it to the column 
# P(mid) = (P(H)+P(L))/2
data['P(mid)'] = (data['P(H)'] - data['P(L)'])/2

# targets to be calculated
# make it equal to P(IPO) then we will just replace
data['Y1'] = data['P(IPO)']
data['Y2'] = data['P(IPO)']

# replace Y1 and change dtype to binary
data.loc[(data['Y1'] < data['P(mid)']),'Y1'] = 1
data.loc[(data['Y1'] > data['P(mid)']),'Y1'] = 0
data['Y1'] = data['Y1'].astype(int)

# replace Y2
data.loc[(data['Y2'] < data['P(1Day)']),'Y2'] = 1
data.loc[(data['Y2'] > data['P(1Day)']),'Y2'] = 0
data['Y2'] = data['Y2'].astype(int)

# Control values to be calculated
data['C3`'] = data['C3']
data['C3`'] = np.where((data['C3'] > 0),1,data['C3`'])
data['C3`'] = np.where((data['C3'] < 0),0,data['C3`'])
data['C3`'] = data['C3`'].astype(int)

# C5`
data['C5`'] = data['C5']/data['C6']

# C6`
data['C6calc'] = ((data['P(IPO)'] - data['P(mid)']) / data['P(mid)']) * 1
data['C6`'] = 0
data['C6`'] = np.where((data['P(IPO)'] > data['P(mid)']),data['C6calc'],data['C6`'])
data['C6`'] = np.where((data['P(IPO)'] < data['P(mid)']),0,data['C6`'])
data['C6`'] = np.where((data['P(mid)']==0),0,data['C6`'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 29 columns):
# I1         682 non-null object
# I2         682 non-null object
# I3         682 non-null object
# P(IPO)     682 non-null float64
# P(H)       682 non-null float64
# P(L)       682 non-null float64
# P(1Day)    682 non-null float64
# C1         682 non-null float64
# C2         682 non-null int64
# C3         682 non-null float64
# C4         682 non-null float64
# C5         682 non-null float64
# C6         682 non-null float64
# C7         682 non-null float64
# T1         682 non-null float64
# T2         682 non-null float64
# T3         682 non-null float64
# T4         682 non-null float64
# T5         682 non-null float64
# S1         682 non-null float64
# S2         682 non-null float64
# S3         682 non-null float64
# P(mid)     682 non-null float64
# Y1         682 non-null int64
# Y2         682 non-null int64
# C3`        682 non-null int64
# C5`        682 non-null float64
# C6calc     682 non-null float64
# C6`        682 non-null float64
# dtypes: float64(22), int64(4), object(3)
# memory usage: 154.6+ KB

# %% [markdown]
# # Descriptive
# 1. https://www.dataquest.io/blog/basic-statistics-with-python-descriptive-statistics/
# - .describe()
# - scipy.stats.describe(y, ddof=1, bias=False)
# - https://realpython.com/python-statistics/
#
#
# Some questions we could also answer: (NOT REQUIRED)
# - how did companies do/were rated based on their EPS?
# - does it have any effect on a company depending on the number of days its in the IPO process
# - does higher IPO price offer better performance/outlook
# - in what condition the company is (EPS, earnings...) based on how many shares they sell
# - does underwriter rating have any effect and is it correlated with positive/neg words, word lenght etc.
# - Lower price more shares? higher earnings less shares?

# %%
cols = ['P(IPO)','P(H)','P(L)','P(1Day)','C1','C3','C4','C5','C6','C7','T1','T2','T3','T4','T5','S1','S2','S3','Y1','Y2','C3`','C5`','C6`']
data[cols].describe()
# Out:
#            P(IPO)        P(H)        P(L)      P(1Day)           C1  \
# count  682.000000  682.000000  682.000000   682.000000   682.000000
# mean    13.837666   15.460739   13.491402    25.497875   145.345203
# std      6.031467    6.608041    5.824909    72.082754   152.236870
# min      3.000000    3.000000    2.500000     0.800000    10.000000
# 25%     10.000000   13.000000   11.000000    11.000000    83.250000
# 50%     13.500000   15.000000   13.000000    14.550000   105.500000
# 75%     17.000000   17.000000   15.000000    20.087500   152.750000
# max     85.000000  135.000000  108.000000  1159.200562  2087.000000
#
#                 C3          C4            C5            C6            C7  ...  \
# count   682.000000  682.000000  6.820000e+02  6.820000e+02    682.000000  ...
# mean      2.548114    0.453424  4.892353e+07  1.230597e+07    449.086347  ...
# std     158.334943    2.445630  1.040179e+08  2.504450e+07   1565.933710  ...
# min    -786.239000   -0.162352  1.383767e+01  1.383767e+01      0.074000  ...
# 25%      -0.747500   -0.013352  1.847794e+07  5.000000e+06     20.474500  ...
# 50%       0.090000    0.011084  2.730589e+07  7.250000e+06     80.998500  ...
# 75%       0.620000    0.033823  4.936364e+07  1.193426e+07    289.758000  ...
# max    3864.500000   13.837666  2.138085e+09  4.212336e+08  30683.000000  ...
#
#                 T4            T5          S1          S2          S3     Y1  \
# count   682.000000    682.000000  682.000000  682.000000  682.000000  682.0
# mean    293.983157    678.266386   68.363160  119.948442  144.567211    0.0
# std     121.821766    473.222400   39.089174   84.864266   69.406693    0.0
# min      13.837666     13.837666    5.000000   13.837666   13.837666    0.0
# 25%     212.250000    460.500000   45.000000   73.000000  100.000000    0.0
# 50%     279.000000    624.000000   60.000000  100.000000  134.000000    0.0
# 75%     353.750000    794.500000   84.750000  141.750000  173.000000    0.0
# max    1058.000000  10277.000000  309.000000  944.000000  883.000000    0.0
#
#                Y2         C3`         C5`         C6`
# count  682.000000  682.000000  682.000000  682.000000
# mean     1.450147    0.538123    4.601533   13.073002
# std      2.943622    0.498910    6.254505    5.667681
# min      0.000000    0.000000    0.283223   -4.000000
# 25%      1.000000    0.000000    2.822675    9.500000
# 50%      1.000000    1.000000    3.731035   13.000000
# 75%      1.000000    1.000000    4.865080   16.000000
# max     20.000000    1.000000   99.787255   45.000000
#
# [8 rows x 23 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 29 columns):
# I1         682 non-null object
# I2         682 non-null object
# I3         682 non-null object
# P(IPO)     682 non-null float64
# P(H)       682 non-null float64
# P(L)       682 non-null float64
# P(1Day)    682 non-null float64
# C1         682 non-null float64
# C2         682 non-null int64
# C3         682 non-null float64
# C4         682 non-null float64
# C5         682 non-null float64
# C6         682 non-null float64
# C7         682 non-null float64
# T1         682 non-null float64
# T2         682 non-null float64
# T3         682 non-null float64
# T4         682 non-null float64
# T5         682 non-null float64
# S1         682 non-null float64
# S2         682 non-null float64
# S3         682 non-null float64
# P(mid)     682 non-null float64
# Y1         682 non-null int64
# Y2         682 non-null int64
# C3`        682 non-null int64
# C5`        682 non-null float64
# C6calc     682 non-null float64
# C6`        682 non-null float64
# dtypes: float64(22), int64(4), object(3)
# memory usage: 154.6+ KB

# %% [markdown]
# # CORRELATION and simple plots
# - https://realpython.com/python-statistics/ (Towards the bottom)
# - also in lectures that professors posted

# %%
cols2 = ['P(IPO)','P(H)','P(L)','P(1Day)','C1','C3','C4','C5','C6','C7','T1','T2','T3','T4','T5','S1','S2','S3']
pd.plotting.scatter_matrix(data[cols2], figsize=(14,14), hist_kwds={'bins':8}, alpha=.5, marker='o', s=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af52366d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af53a9588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af46b0080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af54732b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af49fcb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af54fa080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af56853c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4dbd7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4b946d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af57d9e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af56b41d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af588e0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af589c7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af58e4b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af58cde10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5921c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af590f470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af59a3780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af59eaa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af59fbda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5e0b0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5e17400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af61c3710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af61cfa20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc1d1d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc1d9080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc2a0390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af22236a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af2214a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af454e160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af2fd37f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af1e76e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af1e7d550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af1f52be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af20712b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af2076940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af201cfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af211c6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af211ad30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af2174400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af218fa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af22b3160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af22ba7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af2386e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af236d550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af236cbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc6292b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc5d3940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc5fdfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc5ab6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc554d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc507400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc52ca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc4de160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc48a7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc4b1e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc460550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc40bbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc43c2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc3e3940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc38afd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc3bd6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc365d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc318400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc2c2a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc2f3160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc2597f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc203e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc234550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc19bbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc14f2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc177940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc120fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc0d06a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc0f7d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc0a9400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc052a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc004160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2afc02b7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7fd5e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7f86550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7facbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7f5f2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7f08940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7f30fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7ee16a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7e89d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7ebb400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7e64a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7e15160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7e3d7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7de6e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7d96550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7dbebe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7d722b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7d1a940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7cc2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7cf46a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7c9bd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7c4f400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7c74a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7c27160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7bd07f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7bf9e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7baa550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7b53be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7b042b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7b2b940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7ad5908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7afdf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7aaf668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7a58cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7a0a3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7a31a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af79e3128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af798c7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af79b3e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7966518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af790dba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af78c0278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af78e7908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7890f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7843668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af786bcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af781b3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af77c3a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af77f6128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af779d7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7746e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7776518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7720ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af76d2278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af76f9908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af76a2f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7653668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af767dcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af762f3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af75d6a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7588128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af75b07b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7558e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7509518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7532ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af74e3278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af748c908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af74b4f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7466668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af740dcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af73c03c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af73e7a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af739a128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af73437b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7369e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af731c518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af72c4ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af72f6278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af729e908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7246f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7278668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7222cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af71d23c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af71faa58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af71ac128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af71557b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af717ce48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af712c518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af70d6ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7088278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af70af908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af705af98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af700b668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af7030cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6fe33c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6f8ca58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6fbe128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6f667b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6f10e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6ec1518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6ee7ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6e9a278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6e43908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6e6bf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6e1c668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6dc6cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6df83c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6d9fa58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6d51128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6d7a7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6d20e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6cd2518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6cfaba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6cad278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6c56908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6c7ef98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6c30668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6bd6cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6b893c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6bafa58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6b62128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6b0d7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6b34e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6ae5518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6a8eba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6abf278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6a66908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6a11f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af69c1668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af69eacf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af699c3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6944a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6975128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af691e7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af68c6e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af68f6518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af689eba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6854278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af687a908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6822f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af67d3668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af67facf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af67ac3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6756a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6707128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af67307b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af66d9e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af668a518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af66b0ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6664278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af660d908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6633f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af65e6668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af658dcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af65403c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6568a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af651a128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af64c17b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af64eae48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af649b518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6444ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6477278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af641d908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af63c6f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af63f8668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af639ecf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af63503c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af637ba58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af632c128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af62d37b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af62fee48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af62ae518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6255ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6208278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6231908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6198f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6149668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6171cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af61253c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af60caa58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af60fd128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af60a77b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af604de48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af607f518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af6028ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5fda278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5f81908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5fabf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5f5c668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5f05cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5f383c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5edea58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5e91128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5eba7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5e62e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5dd4518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5dfbba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5dae278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5d55908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5d7ef98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5d30668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5cd9cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5c8a3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5cb3a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5c63128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5c0a7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5c34e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5be6518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5b8dba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5b40278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5b68908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5b11f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5ac1668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5aeacf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5a9c3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5a44a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5a78128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5a1d7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5948e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5979518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5860ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5753278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af577a908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5662f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5595668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af55becf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af54ae3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af53d6a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5289128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af52b07b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af5199e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af50c9518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af50f2ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4fe5278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4f0c908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4f35f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4e28668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4d0fcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4c003c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4c2aa58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4b1c128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4a437b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4a6ce48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af485e518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4745ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2af4776278>]],
#       dtype=object)

# %%
# exlude high correlation --> leakers (All P's and original T's, and C's used for calculation)
# spearman only for continous features so remove categorical features 
# treat them diff in 2 subframes 
# linear relationships --> Ratios!! --> T1 --> (see hints in instructions)
# S --> ratios as well S1/T2 --> reduce the linear correlation

# %%
correlation = data[cols2].corr()
correlation
# Out:
#            P(IPO)      P(H)      P(L)   P(1Day)        C1        C3        C4  \
# P(IPO)   1.000000  0.873460  0.893238  0.042374  0.035671  0.015512 -0.179612
# P(H)     0.873460  1.000000  0.991250  0.041745  0.006692  0.000935 -0.142683
# P(L)     0.893238  0.991250  1.000000  0.045554  0.007979  0.002288 -0.136726
# P(1Day)  0.042374  0.041745  0.045554  1.000000 -0.018470 -0.131505 -0.040351
# C1       0.035671  0.006692  0.007979 -0.018470  1.000000 -0.005625 -0.157349
# C3       0.015512  0.000935  0.002288 -0.131505 -0.005625  1.000000  0.064110
# C4      -0.179612 -0.142683 -0.136726 -0.040351 -0.157349  0.064110  1.000000
# C5       0.376924  0.337936  0.347080 -0.007081  0.013839 -0.000875 -0.055960
# C6       0.364448  0.318719  0.334059 -0.009228  0.016133  0.010556 -0.061887
# C7       0.232042  0.219295  0.232535 -0.017862  0.036192  0.006572 -0.045675
# T1       0.205632  0.187774  0.204926 -0.074031  0.155332  0.002232 -0.116064
# T2       0.181778  0.176294  0.191128 -0.068893  0.146428 -0.006756 -0.110256
# T3       0.175096  0.174755  0.189698 -0.070281  0.142633 -0.006484 -0.095111
# T4       0.193876  0.186800  0.203167 -0.074848  0.135740 -0.006114 -0.090800
# T5       0.103153  0.098284  0.117260 -0.048607  0.063316 -0.008063  0.096820
# S1       0.139574  0.163089  0.179280 -0.057319  0.117963  0.017705 -0.047122
# S2       0.119874  0.140121  0.156897 -0.039423  0.134955  0.010337 -0.061263
# S3       0.133315  0.129317  0.145091 -0.037280  0.139570 -0.010749 -0.074824
#
#                C5        C6        C7        T1        T2        T3        T4  \
# P(IPO)   0.376924  0.364448  0.232042  0.205632  0.181778  0.175096  0.193876
# P(H)     0.337936  0.318719  0.219295  0.187774  0.176294  0.174755  0.186800
# P(L)     0.347080  0.334059  0.232535  0.204926  0.191128  0.189698  0.203167
# P(1Day) -0.007081 -0.009228 -0.017862 -0.074031 -0.068893 -0.070281 -0.074848
# C1       0.013839  0.016133  0.036192  0.155332  0.146428  0.142633  0.135740
# C3      -0.000875  0.010556  0.006572  0.002232 -0.006756 -0.006484 -0.006114
# C4      -0.055960 -0.061887 -0.045675 -0.116064 -0.110256 -0.095111 -0.090800
# C5       1.000000  0.881226  0.408161  0.225970  0.231844  0.235350  0.240714
# C6       0.881226  1.000000  0.396546  0.209504  0.208159  0.215007  0.223200
# C7       0.408161  0.396546  1.000000  0.223589  0.218404  0.221860  0.230916
# T1       0.225970  0.209504  0.223589  1.000000  0.938438  0.946566  0.953051
# T2       0.231844  0.208159  0.218404  0.938438  1.000000  0.957704  0.954716
# T3       0.235350  0.215007  0.221860  0.946566  0.957704  1.000000  0.967073
# T4       0.240714  0.223200  0.230916  0.953051  0.954716  0.967073  1.000000
# T5       0.132492  0.117999  0.127414  0.541429  0.515934  0.579595  0.602962
# S1       0.218000  0.191841  0.263314  0.770421  0.792883  0.802643  0.793479
# S2       0.195887  0.191772  0.328168  0.810344  0.801677  0.810170  0.799840
# S3       0.204072  0.168724  0.180966  0.807482  0.816554  0.830280  0.817173
#
#                T5        S1        S2        S3
# P(IPO)   0.103153  0.139574  0.119874  0.133315
# P(H)     0.098284  0.163089  0.140121  0.129317
# P(L)     0.117260  0.179280  0.156897  0.145091
# P(1Day) -0.048607 -0.057319 -0.039423 -0.037280
# C1       0.063316  0.117963  0.134955  0.139570
# C3      -0.008063  0.017705  0.010337 -0.010749
# C4       0.096820 -0.047122 -0.061263 -0.074824
# C5       0.132492  0.218000  0.195887  0.204072
# C6       0.117999  0.191841  0.191772  0.168724
# C7       0.127414  0.263314  0.328168  0.180966
# T1       0.541429  0.770421  0.810344  0.807482
# T2       0.515934  0.792883  0.801677  0.816554
# T3       0.579595  0.802643  0.810170  0.830280
# T4       0.602962  0.793479  0.799840  0.817173
# T5       1.000000  0.502871  0.492346  0.535725
# S1       0.502871  1.000000  0.743565  0.745152
# S2       0.492346  0.743565  1.000000  0.781472
# S3       0.535725  0.745152  0.781472  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation)

# %% [markdown]
# # Normality Test
# - https://machinelearningmastery.com/a-gentle-introduction-to-normality-tests-in-python/
#
# - Histogram
# - Quantile-Quantile Plot
# - Statistical Normality Tests
# - Shapiro-Wilk Test

# %%
# How do you know if its too much or not

# %%
data[data['P(mid)']==0]
# Out:
#        I1                                           I2       I3     P(IPO)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC     8099  13.837666
# 86    BLT                     BLOUNT INTERNATIONAL INC     1600  13.837666
# 215  ESEA                               EUROSEAS LTD.      4412   7.000000
# 330   KFI                   KKR Financial Holdings LLC     7011  13.837666
# 400  NAUH  National American University Holdings, Inc.     8221  13.837666
# 469  PRGN                        Paragon Shipping Inc.     4412  16.000000
# 597  TRMM                       Access to Money, Inc.   13.8377  13.837666
#
#           P(H)       P(L)     P(1Day)         C1  C2         C3         C4  \
# 10   13.837666  13.837666   13.837666  13.837666  13  13.837666  13.837666
# 86   13.837666  13.837666   13.837666  13.837666  13  13.837666  13.837666
# 215  13.837666  13.837666   13.837666  13.837666  13  13.837666  13.837666
# 330  13.837666  13.837666   13.837666  13.837666  13  13.837666  13.837666
# 400  13.837666  13.837666   13.837666  13.837666  13  13.837666  13.837666
# 469   9.110000   9.110000  144.999970  67.000000   1   0.140000  -0.045155
# 597  13.837666  13.837666   13.837666  13.837666  13  13.837666  13.837666
#
#                C5            C6         C7     T1  ...       T5    S1     S2  \
# 10   1.383767e+01  1.383767e+01  13.837666  332.0  ...    263.0  51.0   65.0
# 86   1.383767e+01  1.383767e+01  13.837666  538.0  ...    631.0  94.0  172.0
# 215  9.602340e+06  9.602340e+06  13.837666  521.0  ...    545.0  72.0   60.0
# 330  1.383767e+01  1.383767e+01  13.837666  246.0  ...  10277.0  64.0   48.0
# 400  1.383767e+01  1.383767e+01  13.837666  290.0  ...    384.0  45.0   68.0
# 469  2.388744e+07  1.030000e+07   4.729000  369.0  ...    362.0  40.0   67.0
# 597  1.383767e+01  1.383767e+01  13.837666  494.0  ...    560.0  46.0  100.0
#
#         S3  IPO/H_dist  IPO/L_dist  H/L_dist  P(IPO)/P(1Day)_dist  P(mid)  Y1  \
# 10    74.0         NaN         NaN       NaN                  NaN     0.0   0
# 86   116.0         NaN         NaN       NaN                  NaN     0.0   0
# 215  121.0         NaN         NaN       NaN                  NaN     0.0   0
# 330  123.0         NaN         NaN       NaN                  NaN     0.0   0
# 400  139.0         NaN         NaN       NaN                  NaN     0.0   0
# 469   83.0       -6.89        6.89       0.0            128.99997     0.0   0
# 597   91.0         NaN         NaN       NaN                  NaN     0.0   0
#
#      Y2  C3`       C5`  C6calc  C6`
# 10   13    1  1.000000     inf  0.0
# 86   13    1  1.000000     inf  0.0
# 215   1    1  1.000000     inf  0.0
# 330  13    1  1.000000     inf  0.0
# 400  13    1  1.000000     inf  0.0
# 469   1    1  2.319169     inf  0.0
# 597  13    1  1.000000     inf  0.0
#
# [7 rows x 33 columns]

# %%
# only for the continous 
# another skewness test --> request skewness from pandas 
# and look at the histograms 
from scipy.stats import shapiro
stat, p = shapiro(test_data)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.083, p=0.000
# Sample does not look Gaussian (reject H0)

# %% [markdown]
# # Normalization

# %%
# now iterate over the remaining columns and create a new zscore column
# should we include the Y1 and Y2 

# THIS IS STANDARDIZATOIN 
# not making this normal --> assumes normality --> need normalization first  
test_columns = list(test_data.columns)
for col in test_columns:
    col_zscore = col + '_zscore'
    test_data[col_zscore] = (test_data[col] - test_data[col].mean())/test_data[col].std(ddof=0)
    
test_data
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         C1    C3        C4          C5          C6        C7     T1       T2  \
# 0    122.0  3.43  0.029074  40962052.0  10600000.0    51.345  470.0  12719.0
# 1    259.0 -1.62 -0.013352  28869196.0   2400000.0    25.936  791.0  21792.0
# 2     90.0 -1.24  0.020715  16845668.0   5000000.0     7.378  201.0   5262.0
# 3    209.0 -0.91  0.020023  14848637.0   4500000.0     8.526  328.0   8259.0
# 4     80.0  0.07 -0.034895  30741716.0   8250000.0   632.298  572.0  14830.0
# ..     ...   ...       ...         ...         ...       ...    ...      ...
# 677  317.0 -0.37  0.004670  38386565.0   9684109.0   186.101  537.0  13359.0
# 678   98.0 -0.41  0.058689  32758082.0   7000000.0    25.461  496.0  13810.0
# 679  112.0  0.60  0.030425  11479826.0   3125000.0    55.431  335.0   9067.0
# 680   78.0  0.20  0.032284  13180261.0   3125000.0   117.857  256.0   7087.0
# 681  281.0  0.76  0.024687  90734200.0  28000000.0  1469.574  413.0  11660.0
#
#           T3     T4  ...  T4_zscore  T5_zscore  S1_zscore  S2_zscore  \
# 0    11560.0  301.0  ...   0.057642   0.024813  -0.162905  -0.034769
# 1    19585.0  510.0  ...   1.774522   0.934144   0.067507   1.439253
# 2     4785.0  128.0  ...  -1.363508  -0.747060  -0.188507  -1.025311
# 3     7574.0  177.0  ...  -0.960986  -0.357951   0.297918  -0.718714
# 4    13176.0  336.0  ...   0.345157   0.088255  -0.034899   0.342581
# ..       ...    ...  ...        ...        ...        ...        ...
# 677  12303.0  329.0  ...   0.287654  -0.004793   0.477127  -0.164482
# 678  12515.0  321.0  ...   0.221936   0.223597   0.041905   0.071361
# 679   8066.0  217.0  ...  -0.632396  -0.514441  -0.777337  -0.447495
# 680   6445.0  182.0  ...  -0.919912  -0.787240  -0.521324  -0.966350
# 681  10544.0  277.0  ...  -0.139512  -0.089382   0.656337  -0.199859
#
#      S3_zscore  C3`_zscore  C5`_zscore  C6`_zscore  Y1_zscore  Y2_zscore
# 0    -0.080270    0.926451   -0.117952    1.046521        NaN  -0.153035
# 1     1.332734   -1.079388    1.188383   -1.072301        NaN  -0.493002
# 2    -1.219324   -1.079388   -0.197187   -1.248869        NaN  -0.493002
# 3    -0.498404   -1.079388   -0.208297   -0.454311        NaN  -0.153035
# 4     0.323445    0.926451   -0.140044    1.223090        NaN  -0.153035
# ..         ...         ...         ...         ...        ...        ...
# 677   0.409956   -1.079388   -0.102027    0.693384        NaN  -0.153035
# 678   0.409956   -1.079388    0.012511   -0.189458        NaN  -0.153035
# 679  -0.786772    0.926451   -0.148480    0.340247        NaN  -0.493002
# 680  -0.642588    0.926451   -0.061417    0.869953        NaN  -0.493002
# 681   0.193679    0.926451   -0.217767    0.340247        NaN  -0.493002
#
# [682 rows x 38 columns]

# %%
stat, p = shapiro(test_data)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.083, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
# logarithmic normalization 
helpful_log = np.log(test_data)
helpful_log.describe()
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /opt/tljh/user/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
#                C1          C3          C4          C5          C6          C7  \
# count  682.000000  367.000000  424.000000  682.000000  682.000000  682.000000
# mean     4.688994   -0.275467   -3.554804   17.127149   15.807661    4.369224
# std      0.759443    1.833985    1.755403    1.593405    1.464534    1.992192
# min      2.302585   -4.605170   -9.701563    2.627394    2.627394   -2.603690
# 25%      4.421835   -1.427116   -4.285248   16.732087   15.424948    3.019157
# 50%      4.658700   -0.544727   -3.528781   17.122613   15.796488    4.394430
# 75%      5.028799    0.562367   -3.095273   17.714724   16.294923    5.669045
# max      7.643483    8.259588    2.627394   21.483176   19.858698   10.331464
#
#                T1          T2          T3          T4  ...   T4_zscore  \
# count  682.000000  682.000000  682.000000  682.000000  ...  299.000000
# mean     6.073648    9.343774    9.227089    5.596162  ...   -0.726593
# std      0.384334    0.612597    0.645691    0.446437  ...    1.333969
# min      2.627394    2.627394    2.627394    2.627394  ...   -8.885639
# 25%      5.858646    9.123719    9.003929    5.357763  ...   -1.274970
# 50%      6.095825    9.394700    9.284937    5.631212  ...   -0.511135
# 75%      6.311281    9.631695    9.528903    5.868590  ...    0.139937
# max      7.467371   10.800718   10.690853    6.964136  ...    1.836764
#
#         T5_zscore   S1_zscore   S2_zscore   S3_zscore  C3`_zscore  C5`_zscore  \
# count  276.000000  270.000000  254.000000  289.000000  367.000000  203.000000
# mean    -1.165839   -0.767478   -1.041141   -0.793121   -0.076395   -1.801963
# std      1.248970    1.295538    1.695576    1.239692    0.000000    1.527742
# min     -6.468604   -4.116349   -7.405374   -5.076754   -0.076395   -7.780150
# 25%     -1.789728   -1.481686   -1.780399   -1.272288   -0.076395   -2.653554
# 50%     -1.057547   -0.502305   -0.775437   -0.616703   -0.076395   -1.879990
# 75%     -0.342527    0.087607   -0.023886    0.001110   -0.076395   -0.848685
# max      3.010555    1.818177    2.273914    2.365280   -0.076395    2.723262
#
#        C6`_zscore  Y1_zscore  Y2_zscore
# count  309.000000        0.0  41.000000
# mean    -0.611172        NaN   1.258976
# std      0.861283        NaN   0.378834
# min     -2.585021        NaN   0.187999
# 25%     -1.078083        NaN   1.067007
# 50%     -0.660069        NaN   1.367766
# 75%     -0.042660        NaN   1.527469
# max      1.729406        NaN   1.841555
#
# [8 rows x 38 columns]

# %%
# COLUMN by column 
# only continous columns 
# notice if its too strong in the histogram 
# kurtosis !! 
# original and new kurtosis value --> function in a for loop 
# do based on how the histogram, kurtosis looks
stat, p = shapiro(test_data)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=nan, p=1.000
# Sample looks Gaussian (fail to reject H0)

# %% [markdown]
# # Standardization

# %%
# min-max standardization (no normalization required)
# sklearn z-score
from mlxtend.preprocessing import minmax_scaling

min_max_scaling = minmax_scaling(test_data, columns=test_data.columns)
min_max_scaling
# Out:
#            C1        C3        C4        C5        C6        C7        T1  \
# 0    0.053924  0.169794  0.013673  0.019158  0.025164  0.001671  0.262742
# 1    0.119884  0.168708  0.010643  0.013502  0.005698  0.000843  0.447632
# 2    0.038517  0.168790  0.013076  0.007879  0.011870  0.000238  0.107802
# 3    0.095811  0.168861  0.013027  0.006945  0.010683  0.000275  0.180952
# 4    0.033702  0.169072  0.009104  0.014378  0.019585  0.020605  0.321492
# ..        ...       ...       ...       ...       ...       ...       ...
# 677  0.147809  0.168977  0.011930  0.017954  0.022990  0.006063  0.301333
# 678  0.042369  0.168969  0.015789  0.015321  0.016618  0.000827  0.277717
# 679  0.049109  0.169186  0.013770  0.005369  0.007419  0.001804  0.184984
# 680  0.032740  0.169100  0.013903  0.006165  0.007419  0.003839  0.139481
# 681  0.130477  0.169220  0.013360  0.042437  0.066471  0.047893  0.229911
#
#            T2        T3        T4        T5        S1        S2        S3  \
# 0    0.259066  0.262782  0.275017  0.065882  0.187500  0.110908  0.144003
# 1    0.444070  0.445425  0.475177  0.107780  0.217105  0.245293  0.256756
# 2    0.107013  0.108588  0.109334  0.030318  0.184211  0.020601  0.053111
# 3    0.168124  0.172064  0.156261  0.048247  0.246711  0.048553  0.110638
# 4    0.302111  0.299561  0.308537  0.068806  0.203947  0.145310  0.176218
# ..        ...       ...       ...       ...       ...       ...       ...
# 677  0.272116  0.279692  0.301833  0.064518  0.269737  0.099082  0.183122
# 678  0.281312  0.284517  0.294171  0.075041  0.213816  0.120584  0.183122
# 679  0.184600  0.183261  0.194570  0.041036  0.108553  0.073280  0.087627
# 680  0.144226  0.146368  0.161050  0.028467  0.141447  0.025976  0.099133
# 681  0.237472  0.239659  0.252032  0.060621  0.292763  0.095857  0.165864
#
#      C3`       C5`       C6`  Y1    Y2
# 0    1.0  0.035990  0.469388 NaN  0.05
# 1    0.0  0.118042  0.224490 NaN  0.00
# 2    0.0  0.031013  0.204082 NaN  0.00
# 3    0.0  0.030315  0.295918 NaN  0.05
# 4    1.0  0.034602  0.489796 NaN  0.05
# ..   ...       ...       ...  ..   ...
# 677  0.0  0.036990  0.428571 NaN  0.05
# 678  0.0  0.044184  0.326531 NaN  0.05
# 679  1.0  0.034072  0.387755 NaN  0.00
# 680  1.0  0.039541  0.448980 NaN  0.00
# 681  1.0  0.029720  0.387755 NaN  0.00
#
# [682 rows x 19 columns]

# %%
stat, p = shapiro(min_max_scaling)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=nan, p=1.000
# Sample looks Gaussian (fail to reject H0)

# %%
min_max_scaling.to_csv('testtttt_2')

# %%
# z-score --> mean of 0, standard deviation = 1
from mlxtend.preprocessing import standardize
standardize(test_data, columns=test_data.columns)
# Out:
#            C1        C3        C4        C5        C6        C7        T1  \
# 0   -0.153460  0.005574 -0.173641 -0.076596 -0.068168 -0.254183  0.028515
# 1    0.747113 -0.026344 -0.191001 -0.192938 -0.395825 -0.270421  1.848932
# 2   -0.363813 -0.023942 -0.177061 -0.308614 -0.291934 -0.282280 -1.497006
# 3    0.418437 -0.021857 -0.177344 -0.327827 -0.311913 -0.281547 -0.776779
# 4   -0.429549 -0.015663 -0.199816 -0.174923 -0.162069  0.117084  0.606965
# ..        ...       ...       ...       ...       ...       ...       ...
# 677  1.128378 -0.018444 -0.183627 -0.101374 -0.104765 -0.168065  0.408477
# 678 -0.311225 -0.018696 -0.161523 -0.155524 -0.212017 -0.270724  0.175963
# 679 -0.219196 -0.012313 -0.173088 -0.360238 -0.366855 -0.251571 -0.737081
# 680 -0.442696 -0.014841 -0.172327 -0.343878 -0.366855 -0.211677 -1.185096
# 681  0.891731 -0.011302 -0.175436  0.402251  0.627106  0.652158 -0.294737
#
#            T2        T3        T4  ...  T4_zscore  T5_zscore  S1_zscore  \
# 0   -0.003836  0.037260  0.057642  ...   0.057642   0.024813  -0.162905
# 1    1.656863  1.691213  1.774522  ...   1.774522   0.934144   0.067507
# 2   -1.368747 -1.359069 -1.363508  ...  -1.363508  -0.747060  -0.188507
# 3   -0.820184 -0.784255 -0.960986  ...  -0.960986  -0.357951   0.297918
# 4    0.382556  0.370317  0.345157  ...   0.345157   0.088255  -0.034899
# ..        ...       ...       ...  ...        ...        ...        ...
# 677  0.113308  0.190392  0.287654  ...   0.287654  -0.004793   0.477127
# 678  0.195858  0.234085  0.221936  ...   0.221936   0.223597   0.041905
# 679 -0.672289 -0.682854 -0.632396  ...  -0.632396  -0.514441  -0.777337
# 680 -1.034704 -1.016942 -0.919912  ...  -0.919912  -0.787240  -0.521324
# 681 -0.197673 -0.172138 -0.139512  ...  -0.139512  -0.089382   0.656337
#
#      S2_zscore  S3_zscore  C3`_zscore  C5`_zscore  C6`_zscore  Y1_zscore  \
# 0    -0.034769  -0.080270    0.926451   -0.117952    1.046521        NaN
# 1     1.439253   1.332734   -1.079388    1.188383   -1.072301        NaN
# 2    -1.025311  -1.219324   -1.079388   -0.197187   -1.248869        NaN
# 3    -0.718714  -0.498404   -1.079388   -0.208297   -0.454311        NaN
# 4     0.342581   0.323445    0.926451   -0.140044    1.223090        NaN
# ..         ...        ...         ...         ...         ...        ...
# 677  -0.164482   0.409956   -1.079388   -0.102027    0.693384        NaN
# 678   0.071361   0.409956   -1.079388    0.012511   -0.189458        NaN
# 679  -0.447495  -0.786772    0.926451   -0.148480    0.340247        NaN
# 680  -0.966350  -0.642588    0.926451   -0.061417    0.869953        NaN
# 681  -0.199859   0.193679    0.926451   -0.217767    0.340247        NaN
#
#      Y2_zscore
# 0    -0.153035
# 1    -0.493002
# 2    -0.493002
# 3    -0.153035
# 4    -0.153035
# ..         ...
# 677  -0.153035
# 678  -0.153035
# 679  -0.493002
# 680  -0.493002
# 681  -0.493002
#
# [682 rows x 38 columns]

# %% [markdown]
# # Discretization

# %%
# optional

# %% [markdown]
# # Conversion

# %%
# optional

# %% [markdown]
# # Outliers

# %% [markdown]
# # Data Reduction

# %% [markdown]
# # PCA
# - do we include Y1, Y2?

# %%
# optional

# %%
# first count how many 0's
data = data.astype(str)
data['P(1Day)'] = data['P(1Day)'].str.strip()
data['P(1Day)'] = data['P(1Day)'].replace('-', 0)
data['P(1Day)'] = data['P(1Day)'].astype(float)

# %%
data = data.astype(str)
data = data.replace('-',0)
data[['P(IPO)','P(H)','P(L)','P(1Day)','C1','C3','C4','C5','C6','C7','T1','T2','T3','T4','T5','S1','S2','S3']] = data[['P(IPO)','P(H)','P(L)','P(1Day)','C1','C3','C4','C5','C6','C7','T1','T2','T3','T4','T5','S1','S2','S3']].astype(float)

# %%
data['C2'] = data['C2'].astype(int)

# %%
data.info()

# %%
# 
data['T2'].value_counts()

# %%
# similarities between different null values 
sim = data[data['P(1Day)']==0]

# %%
sim_missing_val = data[(data['P(1Day)']==0) & (data['P(IPO)']==0) & (data['P(H)']==0)].count()

# %%
# number of zeros in each column 
(data == 0).astype(int).sum(axis=0)

# %%
# Number of non-zero values 
data.astype(bool).sum(axis=0)

# %%
data.head()

# %%
# replace with nulls
# maybe we can run it with zeros/np.nan
cols = ["P(IPO)","P(H)","P(L)","P(1Day)","C1",'C2','C3','C4','C5','C6','C7','T1','T2','T3','T4','T5','S1','S2','S3']
data[cols] = data[cols].replace({0:np.nan})

# Imputate with median
# check if it works right 
data[cols]=data[cols].fillna(data[cols].median())
#.iloc[0]
data['C5'] = data['C5'].fillna(data['C5'].median())

# display
data.head(12)

# %%
data.isnull().sum()

# %%
data.info()

# %%
import matplotlib.pyplot as plt
plt.hist(data['P(IPO)'])
plt.show()

# %%
pd.plotting.scatter_matrix(data[["P(IPO)","P(H)","P(L)"]], figsize=(14,14), hist_kwds={'bins':8}, alpha=.5, marker='o', s=50)

# %%
no_object = data.select_dtypes(exclude=['object'])

# %%
no_object.values

# %%
# normalize with min/max
x = no_object.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled)

# %%
# normalization with sklearn 
from sklearn import preprocessing
# Normalize P(IPO) column (1 column)
x_array = np.array(data['P(IPO)'])
normalized_X = preprocessing.normalize([x_array])

# %%
normalized_X

# %%
# mean normalization
normalized_df=(df-df.mean())/df.std()

# min/max normalization 
normalized_df=(df-df.min())/(df.max()-df.min())

# Note that `select_dtypes` returns a data frame. We are selecting only the columns
numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols].apply(zscore)

# Standardization/normalization

# %%
# STANDARDIZATION
# Get column names first
names = df.columns
# Create the Scaler object
scaler = preprocessing.StandardScaler()
# Fit your data on the scaler object
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=names)

# %%
# Correlation Analysis

# %%
# WHEN YOU HAVE ALL THE CALCULATIONS AND VARIATIONS DOWN DECIDE ON THE ORDER OF THE PROCESSING AND WHAT TO TRY AFTER
# THEN RUN THE MODEL
