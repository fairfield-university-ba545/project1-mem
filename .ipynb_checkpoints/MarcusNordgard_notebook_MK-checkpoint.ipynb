# %%
# imports
import pandas as pd
import numpy as np

# %% [markdown]
# ## To Do:

# %% [markdown]
# - Drop dashes for those columns you use to calculate the target variables (Y1 and Y2) --> drop rows --> MEGAN
# - I3 --> binning --> tech/non-tech, other --> MEGAN
# - Set up the ratios (look at the hints at instructions) --> MARCUS
# - How to handle other missing values --> look at the photo --> ERIK
#
# - Baseline test --> BY MONAY HAVE THE BASELINE TEST
#
# - Normality test (shapiro, histograms, only look the continous) --> function kurtosis --> ERIK
# - Normalization (only continous) (log, etc.) --> aply it based on how the histograms look like (depending on the skew)
# - Standardization (if with z score we have to normalize it, min-max no need)
# - run test and use different columns --> do not use leakers (P, and T's, and S's you use for the calculations)

# %%
data = pd.read_excel('Competition1_raw_data.xlsx')
                    #dtype={'P(IPO)': float, 'P(1Day)': float})
# define dashes as missing --> 0 or NaN
data.head(5)
# Out:
#      I1                                  I2    I3 P(IPO) P(H) P(L) P(1Day)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674     10  9.5  8.5   11.87
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834      8   10    8    7.25
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834      7   14   12     6.7
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834   11.5   16   14   12.39
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492     21   21   19    56.6
#
#     C1 C2    C3  ...        C6       C7   T1     T2     T3   T4    T5  S1  \
# 0  122  1  3.43  ...  10600000   51.345  470  12719  11560  301   690  62
# 1  259  0 -1.62  ...   2400000   25.936  791  21792  19585  510  1120  71
# 2   90  1 -1.24  ...   5000000    7.378  201   5262   4785  128   325  61
# 3  209  1 -0.91  ...   4500000    8.526  328   8259   7574  177   509  80
# 4   80  1  0.07  ...   8250000  632.298  572  14830  13176  336   720  67
#
#     S2   S3
# 0  117  139
# 1  242  237
# 2   33   60
# 3   59  110
# 4  149  167
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Drop Dashes

# %% [markdown]
# - Y1 & Y2: calculated with P(IPO), P(H), P(L), P(1day)
#
# - Y1: set to 1 if P(IPO) < P(mid), where P(mid) = (P(H) + P(L))/2, otherwise 0
# - Y2: set to 1 if P(IPO) < P(1day), otherwise 0

# %%
#P(IPO)
data.loc[data['P(IPO)'] == '-']
# Out:
#        I1                                           I2 I3 P(IPO) P(H) P(L)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC  -      -    -    -
# 86    BLT                     BLOUNT INTERNATIONAL INC  -      -    -    -
# 330   KFI                   KKR Financial Holdings LLC  -      -    -    -
# 400  NAUH  National American University Holdings, Inc.  -      -    -    -
# 597  TRMM                       Access to Money, Inc.   -      -    -    -
#
#     P(1Day) C1 C2 C3  ... C6 C7   T1     T2     T3   T4     T5  S1   S2   S3
# 10        -  -  -  -  ...  -  -  332   7534   6747  169    263  51   65   74
# 86        -  -  -  -  ...  -  -  538  12732  11126  301    631  94  172  116
# 330       -  -  -  -  ...  -  -  246    527   9046  355  10277  64   48  123
# 400       -  -  -  -  ...  -  -  290   8454   7137  192    384  45   68  139
# 597       -  -  -  -  ...  -  -  494  12004  10226  277    560  46  100   91
#
# [5 rows x 22 columns]

# %%
#drop rows that P(IPO) has dashes in
data.drop(10, inplace=True)
data.drop(86, inplace=True)
data.drop(330, inplace=True)
data.drop(400, inplace=True)
data.drop(597, inplace=True)

# %%
#P(IPO)--check if rows dropped
data.loc[data['P(IPO)'] == '-']
# Out:
# Empty DataFrame
# Columns: [I1, I2, I3, P(IPO), P(H), P(L), P(1Day), C1, C2, C3, C4, C5, C6, C7, T1, T2, T3, T4, T5, S1, S2, S3]
# Index: []
#
# [0 rows x 22 columns]

# %%
# P(H)
data.loc[data['P(H)'] == '-']
# Out:
#        I1                            I2    I3 P(IPO) P(H) P(L) P(1Day) C1 C2  \
# 215  ESEA                EUROSEAS LTD.   4412      7    -    -       -  -  -
# 268   GSL             GLOBAL SIGNAL INC     -     18    -    -       -  -  -
# 490   RCH             CHINA CGAME, INC.     -    3.5    -    -       -  -  -
# 560  STRL  STERLING CONSTRUCTION CO INC  1600     15    -    -       -  -  -
# 614  TZOO                 TRAVELZOO INC     -    3.5    -    -       -  -  -
#
#     C3  ...       C6 C7   T1     T2     T3   T4   T5  S1   S2   S3
# 215  -  ...  9602340  -  521  12812  11190  285  545  72   60  121
# 268  -  ...  7000000  -  631  19479  17409  451  976  71  252  155
# 490  -  ...   737000  -  322   9820   8893  230  410  61   92   91
# 560  -  ...  2021758  -  310   7195   6393  172  325  44   65   85
# 614  -  ...        -  -  146   3600   3189   88  181   5   26   38
#
# [5 rows x 22 columns]

# %%
data.drop(215, inplace=True)
data.drop(268, inplace=True)
data.drop(490, inplace=True)
data.drop(560, inplace=True)
data.drop(614, inplace=True)

# %%
# P(H)--check if rows dropped
data.loc[data['P(H)'] == '-']
# Out:
# Empty DataFrame
# Columns: [I1, I2, I3, P(IPO), P(H), P(L), P(1Day), C1, C2, C3, C4, C5, C6, C7, T1, T2, T3, T4, T5, S1, S2, S3]
# Index: []
#
# [0 rows x 22 columns]

# %%
# P(L)---no rows to drop
data.loc[data['P(L)'] == '-']
# Out:
# Empty DataFrame
# Columns: [I1, I2, I3, P(IPO), P(H), P(L), P(1Day), C1, C2, C3, C4, C5, C6, C7, T1, T2, T3, T4, T5, S1, S2, S3]
# Index: []
#
# [0 rows x 22 columns]

# %%
# P(1Day)
data.loc[data['P(1Day)'] == '-']
# Out:
#        I1                                              I2    I3 P(IPO) P(H)  \
# 115  CELM                      CHINA ELECTRIC MOTOR, INC.  3621    4.5  6.5
# 123   CIL  China Intelligent Lighting & Electronics, Inc.  3640      3    5
# 203  ELMD                               Electromed, Inc.   3845      4    6
# 217  EURX                                    EURAND N.V.   2834     16   19
# 286   HPJ                   Highpower International, Inc.  3690   3.25    4
# 357  LZEN                      Lizhan Environmental Corp   2200      4    6
# 401   NBY                   NovaBay Pharmaceuticals, Inc.  2834      4    6
# 410   NIV        NIVS IntelliMedia Technology Group, Inc.  3651    3.5    4
# 496  RGLS                       Regulus Therapeutics Inc.  2834      4   12
# 503  RNIN                             CREATIVE REALITIES,  7373      4    5
# 615  TZYM                       Ocera Therapeutics, Inc.   2834      4   13
# 675  ZGNX                                   ZOGENIX, INC.  2834      4   14
#
#      P(L) P(1Day) C1 C2       C3  ...        C6       C7   T1     T2     T3  \
# 115   5.5       -  -  -        -  ...   5000000        -  351  10352   9296
# 123     4       -  -  -   59.261  ...   3350000   59.261  406  12065  11056
# 203     4       -  -  -   12.999  ...   1700000   12.999  224   6146   5551
# 217    17       -  -  -  109.336  ...   7000000  109.336    -      -      -
# 286     3       -  -  -   73.262  ...    525000   73.262  377  10731   9703
# 357     5       -  -  -   21.612  ...   2500000   21.612  373  10261   9189
# 401     4       -  -  -    1.533  ...   5000000    1.533  382   9959   9215
# 410  3.25       -  -  -  101.048  ...    550000  101.048  451  12594  11210
# 496    10       -  -  -   13.789  ...  11250000   13.789  344  11091  10333
# 503     4       -  -  -  710.216  ...   4500000  710.216  199   5073   4395
# 615    11       -  -  -    8.538  ...  13500000    8.538  299   8480   7904
# 675    12       -  -  -        -  ...  14000000        -  518  16898  15522
#
#       T4   T5   S1   S2   S3
# 115  235  482   52  124  120
# 123  282  667   72  169  182
# 203  154  386   29   52  140
# 217    -    -    -    -    -
# 286  240  486   45  104   96
# 357  236  483   54   64  170
# 401  237  534   73   88  132
# 410  298  565   63  115  170
# 496  258  677  129   87  154
# 503   95  249   27   56   26
# 615  198  550  101   46  127
# 675  370  790   71  146  190
#
# [12 rows x 22 columns]

# %%
data.drop(115, inplace=True)
data.drop(123, inplace=True)
data.drop(203, inplace=True)
data.drop(217, inplace=True)
data.drop(286, inplace=True)
data.drop(357, inplace=True)
data.drop(401, inplace=True)
data.drop(410, inplace=True)
data.drop(496, inplace=True)
data.drop(503, inplace=True)
data.drop(615, inplace=True)
data.drop(675, inplace=True)

# %%
# P(1Day)--check if rows dropped
data.loc[data['P(1Day)'] == '-']
# Out:
# Empty DataFrame
# Columns: [I1, I2, I3, P(IPO), P(H), P(L), P(1Day), C1, C2, C3, C4, C5, C6, C7, T1, T2, T3, T4, T5, S1, S2, S3]
# Index: []
#
# [0 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 0 to 681
# Data columns (total 22 columns):
# I1         660 non-null object
# I2         660 non-null object
# I3         660 non-null object
# P(IPO)     660 non-null object
# P(H)       660 non-null object
# P(L)       660 non-null object
# P(1Day)    660 non-null object
# C1         660 non-null object
# C2         660 non-null object
# C3         660 non-null object
# C4         660 non-null object
# C5         660 non-null object
# C6         660 non-null object
# C7         660 non-null object
# T1         660 non-null object
# T2         660 non-null object
# T3         660 non-null object
# T4         660 non-null object
# T5         660 non-null object
# S1         660 non-null object
# S2         660 non-null object
# S3         660 non-null object
# dtypes: object(22)
# memory usage: 118.6+ KB

# %% [markdown]
# ## I3 Binning

# %% [markdown]
# * One way to convert a continuous variable to categorical is through binning.
# * You can bin your continuous variable using its distribution, any external knowledge, or some other logical reasons.
# * ONLY bin continuous

# %% [markdown]
# ##Ranges taken from internet
# 0100-0999	Agriculture, Forestry and Fishing
# 1000-1499	Mining
# 1500-1799	Construction
# 1800-1999	not used
# 2000-3999	Manufacturing
# 4000-4999	Transportation, Communications, Electric, Gas and Sanitary service
# 5000-5199	Wholesale Trade
# 5200-5999	Retail Trade
# 6000-6799	Finance, Insurance and Real Estate
# 7000-8999	Services
# 9100-9729	Public Administration
# 9900-9999	Nonclassifiable

# %%
data.loc[data['I3'] == '-'] #no missing values
# Out:
# Empty DataFrame
# Columns: [I1, I2, I3, P(IPO), P(H), P(L), P(1Day), C1, C2, C3, C4, C5, C6, C7, T1, T2, T3, T4, T5, S1, S2, S3]
# Index: []
#
# [0 rows x 22 columns]

# %%
# I3 to integers
#data['I3'] = data['I3'].str.strip()
data['I3'] = pd.to_numeric(data['I3'], errors='coerce')
data['I3'].index = data['I3'].index.astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 0 to 681
# Data columns (total 22 columns):
# I1         660 non-null object
# I2         660 non-null object
# I3         656 non-null float64
# P(IPO)     660 non-null object
# P(H)       660 non-null object
# P(L)       660 non-null object
# P(1Day)    660 non-null object
# C1         660 non-null object
# C2         660 non-null object
# C3         660 non-null object
# C4         660 non-null object
# C5         660 non-null object
# C6         660 non-null object
# C7         660 non-null object
# T1         660 non-null object
# T2         660 non-null object
# T3         660 non-null object
# T4         660 non-null object
# T5         660 non-null object
# S1         660 non-null object
# S2         660 non-null object
# S3         660 non-null object
# dtypes: float64(1), object(21)
# memory usage: 118.6+ KB

# %%
#2000-3999	Manufacturing
def assign_bins(I3):
    if (I3 >= 2000) and (I3 <= 3999):       
        return(1)
    else:       
        return(0)

    
data['bins'] = data['I3'].apply(assign_bins)  # Creating a new column bins in the dataframe

data.head()
# Out:
#      I1                                  I2      I3 P(IPO) P(H) P(L) P(1Day)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674.0     10  9.5  8.5   11.87
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834.0      8   10    8    7.25
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834.0      7   14   12     6.7
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834.0   11.5   16   14   12.39
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492.0     21   21   19    56.6
#
#     C1 C2    C3  ...       C7   T1     T2     T3   T4    T5  S1   S2   S3 bins
# 0  122  1  3.43  ...   51.345  470  12719  11560  301   690  62  117  139    1
# 1  259  0 -1.62  ...   25.936  791  21792  19585  510  1120  71  242  237    1
# 2   90  1 -1.24  ...    7.378  201   5262   4785  128   325  61   33   60    1
# 3  209  1 -0.91  ...    8.526  328   8259   7574  177   509  80   59  110    1
# 4   80  1  0.07  ...  632.298  572  14830  13176  336   720  67  149  167    0
#
# [5 rows x 23 columns]

# %%
#services and other (7000-8999)
def assign_bins(I3):  
    if (I3 >= 7000) and (I3 <= 8999):       # Creating a bin value of 1 for services
        return(1)
    else:                               # Creating a bin value of 0 for all other I3 values
        return(0)
   

data['bins'] = data['I3'].apply(assign_bins)  # Creating a new column bins in the dataframe

data.head()
# Out:
#      I1                                  I2      I3 P(IPO) P(H) P(L) P(1Day)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674.0     10  9.5  8.5   11.87
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834.0      8   10    8    7.25
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834.0      7   14   12     6.7
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834.0   11.5   16   14   12.39
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492.0     21   21   19    56.6
#
#     C1 C2    C3  ...       C7   T1     T2     T3   T4    T5  S1   S2   S3 bins
# 0  122  1  3.43  ...   51.345  470  12719  11560  301   690  62  117  139    0
# 1  259  0 -1.62  ...   25.936  791  21792  19585  510  1120  71  242  237    0
# 2   90  1 -1.24  ...    7.378  201   5262   4785  128   325  61   33   60    0
# 3  209  1 -0.91  ...    8.526  328   8259   7574  177   509  80   59  110    0
# 4   80  1  0.07  ...  632.298  572  14830  13176  336   720  67  149  167    0
#
# [5 rows x 23 columns]

# %%
#1500-1799	Construction
def assign_bins(I3):
    if (I3 >= 1500) and (I3 <= 17999):       
        return(1)
    else:       
        return(0)

    
data['bins'] = data['I3'].apply(assign_bins)  # Creating a new column bins in the dataframe

data.head()
# Out:
#      I1                                  I2      I3 P(IPO) P(H) P(L) P(1Day)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674.0     10  9.5  8.5   11.87
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834.0      8   10    8    7.25
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834.0      7   14   12     6.7
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834.0   11.5   16   14   12.39
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492.0     21   21   19    56.6
#
#     C1 C2    C3  ...       C7   T1     T2     T3   T4    T5  S1   S2   S3 bins
# 0  122  1  3.43  ...   51.345  470  12719  11560  301   690  62  117  139    1
# 1  259  0 -1.62  ...   25.936  791  21792  19585  510  1120  71  242  237    1
# 2   90  1 -1.24  ...    7.378  201   5262   4785  128   325  61   33   60    1
# 3  209  1 -0.91  ...    8.526  328   8259   7574  177   509  80   59  110    1
# 4   80  1  0.07  ...  632.298  572  14830  13176  336   720  67  149  167    1
#
# [5 rows x 23 columns]

# %%
#4000-4999	Transportation, Communications, Electric, Gas and Sanitary service
def assign_bins(I3):
    if (I3 >= 4000) and (I3 <= 4999):       
        return(1)
    else:       
        return(0)

    
data['bins'] = data['I3'].apply(assign_bins)  # Creating a new column bins in the dataframe

data.head()
# Out:
#      I1                                  I2      I3 P(IPO) P(H) P(L) P(1Day)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674.0     10  9.5  8.5   11.87
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834.0      8   10    8    7.25
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834.0      7   14   12     6.7
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834.0   11.5   16   14   12.39
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492.0     21   21   19    56.6
#
#     C1 C2    C3  ...       C7   T1     T2     T3   T4    T5  S1   S2   S3 bins
# 0  122  1  3.43  ...   51.345  470  12719  11560  301   690  62  117  139    0
# 1  259  0 -1.62  ...   25.936  791  21792  19585  510  1120  71  242  237    0
# 2   90  1 -1.24  ...    7.378  201   5262   4785  128   325  61   33   60    0
# 3  209  1 -0.91  ...    8.526  328   8259   7574  177   509  80   59  110    0
# 4   80  1  0.07  ...  632.298  572  14830  13176  336   720  67  149  167    1
#
# [5 rows x 23 columns]

# %%
#5000-5199	Wholesale Trade
def assign_bins(I3):
    if (I3 >= 5000) and (I3 <= 5199):       
        return(1)
    else:       
        return(0)

    
data['bins'] = data['I3'].apply(assign_bins)  # Creating a new column bins in the dataframe

data.head()
# Out:
#      I1                                  I2      I3 P(IPO) P(H) P(L) P(1Day)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674.0     10  9.5  8.5   11.87
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834.0      8   10    8    7.25
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834.0      7   14   12     6.7
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834.0   11.5   16   14   12.39
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492.0     21   21   19    56.6
#
#     C1 C2    C3  ...       C7   T1     T2     T3   T4    T5  S1   S2   S3 bins
# 0  122  1  3.43  ...   51.345  470  12719  11560  301   690  62  117  139    0
# 1  259  0 -1.62  ...   25.936  791  21792  19585  510  1120  71  242  237    0
# 2   90  1 -1.24  ...    7.378  201   5262   4785  128   325  61   33   60    0
# 3  209  1 -0.91  ...    8.526  328   8259   7574  177   509  80   59  110    0
# 4   80  1  0.07  ...  632.298  572  14830  13176  336   720  67  149  167    0
#
# [5 rows x 23 columns]

# %%
#5200-5999	Retail Trade
def assign_bins(I3):
    if (I3 >= 5200) and (I3 <= 5999):       
        return(1)
    else:       
        return(0)

    
data['bins'] = data['I3'].apply(assign_bins)  # Creating a new column bins in the dataframe

data.head()
# Out:
#      I1                                  I2      I3 P(IPO) P(H) P(L) P(1Day)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674.0     10  9.5  8.5   11.87
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834.0      8   10    8    7.25
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834.0      7   14   12     6.7
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834.0   11.5   16   14   12.39
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492.0     21   21   19    56.6
#
#     C1 C2    C3  ...       C7   T1     T2     T3   T4    T5  S1   S2   S3 bins
# 0  122  1  3.43  ...   51.345  470  12719  11560  301   690  62  117  139    0
# 1  259  0 -1.62  ...   25.936  791  21792  19585  510  1120  71  242  237    0
# 2   90  1 -1.24  ...    7.378  201   5262   4785  128   325  61   33   60    0
# 3  209  1 -0.91  ...    8.526  328   8259   7574  177   509  80   59  110    0
# 4   80  1  0.07  ...  632.298  572  14830  13176  336   720  67  149  167    0
#
# [5 rows x 23 columns]

# %%
#6000-6799	Finance, Insurance and Real Estate
def assign_bins(I3):
    if (I3 >= 6000) and (I3 <= 6799):       
        return(1)
    else:       
        return(0)

    
data['bins'] = data['I3'].apply(assign_bins)  # Creating a new column bins in the dataframe

data.head()
# Out:
#      I1                                  I2      I3 P(IPO) P(H) P(L) P(1Day)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674.0     10  9.5  8.5   11.87
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834.0      8   10    8    7.25
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834.0      7   14   12     6.7
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834.0   11.5   16   14   12.39
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492.0     21   21   19    56.6
#
#     C1 C2    C3  ...       C7   T1     T2     T3   T4    T5  S1   S2   S3 bins
# 0  122  1  3.43  ...   51.345  470  12719  11560  301   690  62  117  139    0
# 1  259  0 -1.62  ...   25.936  791  21792  19585  510  1120  71  242  237    0
# 2   90  1 -1.24  ...    7.378  201   5262   4785  128   325  61   33   60    0
# 3  209  1 -0.91  ...    8.526  328   8259   7574  177   509  80   59  110    0
# 4   80  1  0.07  ...  632.298  572  14830  13176  336   720  67  149  167    0
#
# [5 rows x 23 columns]

# %%
#bin all columns--or just continuous?
#consider other binning ideas

#google SIC codes 
#they have bins
####use code from mini project two--winbins
