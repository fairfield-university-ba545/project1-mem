# %%
# imports
import pandas as pd
import numpy as np

# %%
# Need to do some calculation for Y, S,T (use ratios for prime)
# purple group they in text --> not as useful --> not all of them are ID like features some of them might be useful 
    # 1 tend to be very useful

# %%
# CHECK HIGH AND LOW !!! --> INVALID VALUES
# TRULY MISSING VALUES??? CHECK
# are HIGH LOW CONNECTED TO NULL VALUES 
# WHAT DOES - mean --> when does it happen 

# high and low of the IPO
# Pmid fair estimation of P(H) or P(L) --> UNDERPRICING DETECTING (Y1, Y2)

# %%
data = pd.read_excel('Competition1_raw_data.xlsx')
                    #dtype={'P(IPO)': float, 'P(1Day)': float})
# define dashes as missing --> 0 or NaN
data.head(40)
# Out:
#       I1                                     I2    I3 P(IPO)  P(H)  P(L)  \
# 0   AATI     ADVANCED ANALOGIC TECHNOLOGIES INC  3674     10   9.5   8.5
# 1   ABPI        ACCENTIA BIOPHARMACEUTICALS INC  2834      8    10     8
# 2   ACAD             ACADIA PHARMACEUTICALS INC  2834      7    14    12
# 3   ACHN          ACHILLION PHARMACEUTICALS INC  2834   11.5    16    14
# 4   ACLI        AMERICAN COMMERCIAL LINES INC.   4492     21    21    19
# 5   ACOM                     Ancestry.com Inc.   7379   13.5  14.5  12.5
# 6   ACOR                ACORDA THERAPEUTICS INC  2836      6    13    11
# 7   ACRX             ACELRX PHARMACEUTICALS INC  2834      5    14    12
# 8   ACTV                     ACTIVE NETWORK INC  7372     15    18    16
# 9    ACW                          ACCURIDE CORP  3714      9    19    17
# 10  ADKU             ADCARE HEALTH SYSTEMS, INC     -      -     -     -
# 11  ADLS  Advanced Life Sciences Holdings, Inc.  2854      5     9     8
# 12  ADZA                  ADEZA BIOMEDICAL CORP  2835     16    16    14
# 13  AFFY                            AFFYMAX INC  2834     25    24    22
# 14  AGAM            AGA Medical Holdings, Inc.   3845   14.5    16    15
# 15    AH                           R1 RCM INC.   7389     12    16    14
# 16  AHII           ANIMAL HEALTH HOLDINGS, INC.  5047     11    12    10
# 17  AIMC         Altra Industrial Motion Corp.   3568   13.5    16    14
# 18  AIRV                            AIRVANA INC  3661      7    10     8
# 19  ALGT                   Allegiant Travel CO   4512     18    17    15
# 20  ALIM                  ALIMERA SCIENCES INC   2834     11    17    15
# 21   ALJ                 Alon USA Energy, Inc.   2911     16    16    14
# 22  ALLI                  ALLION HEALTHCARE INC  8099     13    14    12
# 23  ALNY          ALNYLAM PHARMACEUTICALS, INC.  2834      6     8     6
# 24  ALTU            Altus Pharmaceuticals Inc.   2836     15    16    14
# 25  ALXA           Alexza Pharmaceuticals Inc.   2834      8    12    10
# 26  AMBA                         AMBARELLA INC   3674      6    11     9
# 27  AMIS                      AMIS HOLDINGS INC  3674     20    20    18
# 28  AMRC                         Ameresco, Inc.  4931     10    16    14
# 29  ANAC           Anacor Pharmaceuticals, Inc.  2834      5    18    16
# 30  ANFI               Amira Nature Foods Ltd.   2000     10    15    13
# 31  ANGI                    Angie's List, Inc.   7379     13    13    11
# 32  ANGO                      ANGIODYNAMICS INC  3841     11    14    12
# 33  AONE                    B456 SYSTEMS, INC.   3690   13.5   9.5     8
# 34  AOSL        ALPHA & OMEGA SEMICONDUCTOR Ltd  3674     18    20    16
# 35  APEI          AMERICAN PUBLIC EDUCATION INC  8221     20    19    18
# 36  APKT                        ACME PACKET INC  3576    9.5   7.5   6.5
# 37  ARAY                        ACCURAY INC CIK  3841     18    18    17
# 38  ARBX                           ARBINET Corp  7389   17.5    16    14
# 39  ARCL             Archipelago Learning, Inc.  8200   16.5    17    15
#
#    P(1Day)   C1 C2     C3  ...        C6       C7   T1     T2     T3   T4  \
# 0    11.87  122  1   3.43  ...  10600000   51.345  470  12719  11560  301
# 1     7.25  259  0  -1.62  ...   2400000   25.936  791  21792  19585  510
# 2      6.7   90  1  -1.24  ...   5000000    7.378  201   5262   4785  128
# 3    12.39  209  1  -0.91  ...   4500000    8.526  328   8259   7574  177
# 4     56.6   80  1   0.07  ...   8250000  632.298  572  14830  13176  336
# 5     14.2   94  1   0.06  ...   7407407  197.591  510  17999  13934  328
# 6     6.72  128  1  -1.87  ...   5500000    5.146  495  15758  13953  379
# 7     4.55   91  0  -0.74  ...   8000000        -  334  11226  10056  276
# 8     15.9  100  1  -0.51  ...  11000000    279.6  620  14813  13463  335
# 9        0  106  1   1.49  ...  11000000  494.008  385   9134   8107  198
# 10       -    -  -      -  ...         -        -  332   7534   6747  169
# 11       6   99  1 -398.1  ...   7000000     0.32  253   5788   5200  138
# 12    19.7  126  1   0.27  ...   3750000   26.499  206   5732   4963  141
# 13   33.88  140  1  -2.19  ...   3700000    0.074  416  10562   9835  231
# 14    14.6  488  1   0.18  ...  13750000  166.896  624  18633  16471  380
# 15   13.55  233  1   0.17  ...  10000000  510.192  586  18142  15782  413
# 16   12.45  125  1   0.31  ...  11800000  571.192  269   6456   5687  140
# 17   14.29   77  1   0.14  ...  10000000  363.465  391  11322   9589  247
# 18    7.17   92  1   1.18  ...   8300000   170.27  528  13516  12431  323
# 19    25.1  207  1   0.63  ...   5000000    132.5  512  11684  10189  267
# 20      11  174  1  -1.43  ...   6550000        -  473  13801  12500  296
# 21   17.25   78  1   0.67  ...  10200000  1707.56  591  14315  12418  353
# 22    16.5   68  1  -0.86  ...   4000000   64.606  279   6569   5889  149
# 23    6.01   91  1 -29.64  ...   5000000    0.176  248   6533   5977  150
# 24   16.82  101  1  -1.39  ...   7000000     3.88  263   8601   7663  184
# 25    85.1   76  1  -19.2  ...   5500000     2.23  259   7830   7033  156
# 26    6.06  488  1   0.38  ...   6000000   94.739  499  13534  12580  337
# 27    20.1   40  1  -0.41  ...  30000000  345.322  527  15006      0  334
# 28   10.17  113  1    0.5  ...   8696820  428.516  641  18484  16496  436
# 29    5.09   75  1  -0.93  ...  12000000   18.643  403  12099  11038  281
# 30    9.58   42  1   0.22  ...   9000000  257.056  578  16953  15176  378
# 31   16.26   84  1  -0.49  ...   8793408   59.039  511  16279  13883  348
# 32    12.5   83  0   0.13  ...   1950000   38.434  329   7154   6296  175
# 33   20.29  412  1  -9.04  ...  28180501   68.525  536  13374  12334  304
# 34    17.7   29  1  -0.02  ...   5085985  185.076  388  12190  11085  274
# 35   35.92   94  1   0.15  ...   4687500   40.045  400  10135   9114  233
# 36   15.91  133  1      0  ...  11474528    36.12  547  14728  13418  345
# 37   28.47   87  1  -0.64  ...  16000000   52.897  471  12754  11459  308
# 38     116  160  1    1.4  ...   6535405  519.966  322   7738   6866  186
# 39   18.77   78  1   0.04  ...   6250000   32.068  535  17094  14915  347
#
#       T5   S1   S2   S3
# 0    690   62  117  139
# 1   1120   71  242  237
# 2    325   61   33   60
# 3    509   80   59  110
# 4    720   67  149  167
# 5    815   62   96  181
# 6    698   82  106  135
# 7     -1   55  120  122
# 8    917   58  124  234
# 9    459   81   90  147
# 10   263   51   65   74
# 11   385   29   41   70
# 12   259   21   43   80
# 13   726   81  118  138
# 14   909   98  256  172
# 15   649   98   92  155
# 16   336   36   33   83
# 17   603   72  134  133
# 18   523   54   75  117
# 19   429   52   78   91
# 20   768   66  136  182
# 21   675   57   73   88
# 22   308   29   93   97
# 23   384   58   39  100
# 24   473   63   51   93
# 25   453   36   85  119
# 26   777   91   88  237
# 27   809   46  181  167
# 28   898  125  164  184
# 29   626  103  102  162
# 30   885   81   87  169
# 31   776   71   99  110
# 32   384   47   47   94
# 33   748   66  149  194
# 34   677   56  116  160
# 35   545   47   69   98
# 36   841   60  149  176
# 37   601   65   85  103
# 38   342   35   60  125
# 39   927   78   84  157
#
# [40 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 22 columns):
# I1         682 non-null object
# I2         682 non-null object
# I3         682 non-null object
# P(IPO)     682 non-null object
# P(H)       682 non-null object
# P(L)       682 non-null object
# P(1Day)    682 non-null object
# C1         682 non-null object
# C2         682 non-null object
# C3         682 non-null object
# C4         682 non-null object
# C5         682 non-null object
# C6         682 non-null object
# C7         682 non-null object
# T1         682 non-null object
# T2         682 non-null object
# T3         682 non-null object
# T4         682 non-null object
# T5         682 non-null object
# S1         682 non-null object
# S2         682 non-null object
# S3         682 non-null object
# dtypes: object(22)
# memory usage: 117.3+ KB

# %% [markdown]
# # PLAN
# - In every stage make e.g. 5 different ways of doing that --> store that in a seperate notebook
# - Connect pipelines in different ways (most probable)
# - In the end have multiple notebooks/files to be tested

# %% [markdown]
# # Data Cleaning
# 1. Finding Null/wrong values
#     - '-' --> some
#     - dtype --> All
#     - -1 --> T5, S1
#     - 0 (P(1Day)), T2, T3, T4
#     - I3 industry type
#     - P(H) < P(L)
#     - C2 (how to fill that)
# 2. Make assumptions to why this happen and how to resolve/imputate it
#     STEP1: Dashes (P(H), P(L)) --> those that have P(IPO) average distance (MEGAN)
#     STEP2: find out what is the industry classifier (I3) --> that have dashes (MEGAN)
#     STEP3: infer average distance for P(1Day) --> cannot be more than 3x price --> mean distance (MEGAN)
#     STEP4: C1 --> C7 --> those that have information give best possible guess to fill in the dash (e.g. average distance)
#     STEP5: ASSUMTION -1 means none
#     STEP6: appropriate guess for 0
#     STEP6: data[data['P(H)'] < data['P(L)']] --> replace with best guess/switch
#     STEP7: Dashes --> replace all dashes with NaN
#
#     STEP8: replace nan's with imputation method: Median, mode, mean

# %%
# Companies that have dashes in some places 
data[(data['P(1Day)']=='-') & (data['P(IPO)']=='-') & (data['P(H)']=='-')& (data['C1']=='-')& (data['C2']=='-')& 
     (data['C3']=='-')& (data['C4']=='-')& (data['C5']=='-')& (data['C6']=='-')& (data['C7']=='-')& (data['I3']=='-')]
# Out:
#        I1                                           I2 I3 P(IPO) P(H) P(L)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC  -      -    -    -
# 86    BLT                     BLOUNT INTERNATIONAL INC  -      -    -    -
# 330   KFI                   KKR Financial Holdings LLC  -      -    -    -
# 400  NAUH  National American University Holdings, Inc.  -      -    -    -
# 597  TRMM                       Access to Money, Inc.   -      -    -    -
#
#     P(1Day) C1 C2 C3  ... C6 C7   T1     T2     T3   T4     T5  S1   S2   S3
# 10        -  -  -  -  ...  -  -  332   7534   6747  169    263  51   65   74
# 86        -  -  -  -  ...  -  -  538  12732  11126  301    631  94  172  116
# 330       -  -  -  -  ...  -  -  246    527   9046  355  10277  64   48  123
# 400       -  -  -  -  ...  -  -  290   8454   7137  192    384  45   68  139
# 597       -  -  -  -  ...  -  -  494  12004  10226  277    560  46  100   91
#
# [5 rows x 22 columns]

# %%
data['I3'].value_counts().head(16)
# Out:
# 2834    76
# 7372    49
# 3674    36
# 7389    32
# 3841    30
# 1311    18
# 3845    14
# 7373    12
# 5812    11
# 4412    10
# 7371    10
# 7374     9
# 4899     9
# 8731     9
# 2836     9
# -        8
# Name: I3, dtype: int64

# %%
# I3 --> C7 
data.loc[data['P(IPO)'] == '-']
# Out:
#        I1                                           I2 I3 P(IPO) P(H) P(L)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC  -      -    -    -
# 86    BLT                     BLOUNT INTERNATIONAL INC  -      -    -    -
# 330   KFI                   KKR Financial Holdings LLC  -      -    -    -
# 400  NAUH  National American University Holdings, Inc.  -      -    -    -
# 597  TRMM                       Access to Money, Inc.   -      -    -    -
#
#     P(1Day) C1 C2 C3  ... C6 C7   T1     T2     T3   T4     T5  S1   S2   S3
# 10        -  -  -  -  ...  -  -  332   7534   6747  169    263  51   65   74
# 86        -  -  -  -  ...  -  -  538  12732  11126  301    631  94  172  116
# 330       -  -  -  -  ...  -  -  246    527   9046  355  10277  64   48  123
# 400       -  -  -  -  ...  -  -  290   8454   7137  192    384  45   68  139
# 597       -  -  -  -  ...  -  -  494  12004  10226  277    560  46  100   91
#
# [5 rows x 22 columns]

# %%
# I3 --> C7 
data.loc[data['P(IPO)'] == 0]
# Out:
# Empty DataFrame
# Columns: [I1, I2, I3, P(IPO), P(H), P(L), P(1Day), C1, C2, C3, C4, C5, C6, C7, T1, T2, T3, T4, T5, S1, S2, S3]
# Index: []
#
# [0 rows x 22 columns]

# %%
data.loc[data['P(H)'] == '-']
# Out:
#        I1                                           I2    I3 P(IPO) P(H) P(L)  \
# 10   ADKU                   ADCARE HEALTH SYSTEMS, INC     -      -    -    -
# 86    BLT                     BLOUNT INTERNATIONAL INC     -      -    -    -
# 215  ESEA                               EUROSEAS LTD.   4412      7    -    -
# 268   GSL                            GLOBAL SIGNAL INC     -     18    -    -
# 330   KFI                   KKR Financial Holdings LLC     -      -    -    -
# 400  NAUH  National American University Holdings, Inc.     -      -    -    -
# 490   RCH                            CHINA CGAME, INC.     -    3.5    -    -
# 560  STRL                 STERLING CONSTRUCTION CO INC  1600     15    -    -
# 597  TRMM                       Access to Money, Inc.      -      -    -    -
# 614  TZOO                                TRAVELZOO INC     -    3.5    -    -
#
#     P(1Day) C1 C2 C3  ...       C6 C7   T1     T2     T3   T4     T5  S1   S2  \
# 10        -  -  -  -  ...        -  -  332   7534   6747  169    263  51   65
# 86        -  -  -  -  ...        -  -  538  12732  11126  301    631  94  172
# 215       -  -  -  -  ...  9602340  -  521  12812  11190  285    545  72   60
# 268       -  -  -  -  ...  7000000  -  631  19479  17409  451    976  71  252
# 330       -  -  -  -  ...        -  -  246    527   9046  355  10277  64   48
# 400       -  -  -  -  ...        -  -  290   8454   7137  192    384  45   68
# 490       -  -  -  -  ...   737000  -  322   9820   8893  230    410  61   92
# 560       -  -  -  -  ...  2021758  -  310   7195   6393  172    325  44   65
# 597       -  -  -  -  ...        -  -  494  12004  10226  277    560  46  100
# 614       -  -  -  -  ...        -  -  146   3600   3189   88    181   5   26
#
#       S3
# 10    74
# 86   116
# 215  121
# 268  155
# 330  123
# 400  139
# 490   91
# 560   85
# 597   91
# 614   38
#
# [10 rows x 22 columns]

# %%
data.loc[data['P(1Day)'] == '-']
# Out:
#        I1                                              I2    I3 P(IPO) P(H)  \
# 10   ADKU                      ADCARE HEALTH SYSTEMS, INC     -      -    -
# 86    BLT                        BLOUNT INTERNATIONAL INC     -      -    -
# 115  CELM                      CHINA ELECTRIC MOTOR, INC.  3621    4.5  6.5
# 123   CIL  China Intelligent Lighting & Electronics, Inc.  3640      3    5
# 203  ELMD                               Electromed, Inc.   3845      4    6
# 215  ESEA                                  EUROSEAS LTD.   4412      7    -
# 217  EURX                                    EURAND N.V.   2834     16   19
# 268   GSL                               GLOBAL SIGNAL INC     -     18    -
# 286   HPJ                   Highpower International, Inc.  3690   3.25    4
# 330   KFI                      KKR Financial Holdings LLC     -      -    -
# 357  LZEN                      Lizhan Environmental Corp   2200      4    6
# 400  NAUH     National American University Holdings, Inc.     -      -    -
# 401   NBY                   NovaBay Pharmaceuticals, Inc.  2834      4    6
# 410   NIV        NIVS IntelliMedia Technology Group, Inc.  3651    3.5    4
# 490   RCH                               CHINA CGAME, INC.     -    3.5    -
# 496  RGLS                       Regulus Therapeutics Inc.  2834      4   12
# 503  RNIN                             CREATIVE REALITIES,  7373      4    5
# 560  STRL                    STERLING CONSTRUCTION CO INC  1600     15    -
# 597  TRMM                          Access to Money, Inc.      -      -    -
# 614  TZOO                                   TRAVELZOO INC     -    3.5    -
# 615  TZYM                       Ocera Therapeutics, Inc.   2834      4   13
# 675  ZGNX                                   ZOGENIX, INC.  2834      4   14
#
#      P(L) P(1Day) C1 C2       C3  ...        C6       C7   T1     T2     T3  \
# 10      -       -  -  -        -  ...         -        -  332   7534   6747
# 86      -       -  -  -        -  ...         -        -  538  12732  11126
# 115   5.5       -  -  -        -  ...   5000000        -  351  10352   9296
# 123     4       -  -  -   59.261  ...   3350000   59.261  406  12065  11056
# 203     4       -  -  -   12.999  ...   1700000   12.999  224   6146   5551
# 215     -       -  -  -        -  ...   9602340        -  521  12812  11190
# 217    17       -  -  -  109.336  ...   7000000  109.336    -      -      -
# 268     -       -  -  -        -  ...   7000000        -  631  19479  17409
# 286     3       -  -  -   73.262  ...    525000   73.262  377  10731   9703
# 330     -       -  -  -        -  ...         -        -  246    527   9046
# 357     5       -  -  -   21.612  ...   2500000   21.612  373  10261   9189
# 400     -       -  -  -        -  ...         -        -  290   8454   7137
# 401     4       -  -  -    1.533  ...   5000000    1.533  382   9959   9215
# 410  3.25       -  -  -  101.048  ...    550000  101.048  451  12594  11210
# 490     -       -  -  -        -  ...    737000        -  322   9820   8893
# 496    10       -  -  -   13.789  ...  11250000   13.789  344  11091  10333
# 503     4       -  -  -  710.216  ...   4500000  710.216  199   5073   4395
# 560     -       -  -  -        -  ...   2021758        -  310   7195   6393
# 597     -       -  -  -        -  ...         -        -  494  12004  10226
# 614     -       -  -  -        -  ...         -        -  146   3600   3189
# 615    11       -  -  -    8.538  ...  13500000    8.538  299   8480   7904
# 675    12       -  -  -        -  ...  14000000        -  518  16898  15522
#
#       T4     T5   S1   S2   S3
# 10   169    263   51   65   74
# 86   301    631   94  172  116
# 115  235    482   52  124  120
# 123  282    667   72  169  182
# 203  154    386   29   52  140
# 215  285    545   72   60  121
# 217    -      -    -    -    -
# 268  451    976   71  252  155
# 286  240    486   45  104   96
# 330  355  10277   64   48  123
# 357  236    483   54   64  170
# 400  192    384   45   68  139
# 401  237    534   73   88  132
# 410  298    565   63  115  170
# 490  230    410   61   92   91
# 496  258    677  129   87  154
# 503   95    249   27   56   26
# 560  172    325   44   65   85
# 597  277    560   46  100   91
# 614   88    181    5   26   38
# 615  198    550  101   46  127
# 675  370    790   71  146  190
#
# [22 rows x 22 columns]

# %% [markdown]
# ## IMPUTING P(H)

# %%
data['P(H)'] =
# Out:
#   File "<ipython-input-8-d43324ab83a6>", line 1
#     data['P(H)'] =
#                    ^
# SyntaxError: invalid syntax

# %%
data = data.replace('-',np.nan)

# %%
data.loc[data['I2'] == 'EUROSEAS LTD.', 'P(H)'] = 8

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 22 columns):
# I1         682 non-null object
# I2         682 non-null object
# I3         674 non-null object
# P(IPO)     677 non-null float64
# P(H)       672 non-null float64
# P(L)       672 non-null float64
# P(1Day)    660 non-null float64
# C1         660 non-null float64
# C2         660 non-null float64
# C3         646 non-null float64
# C4         660 non-null float64
# C5         676 non-null float64
# C6         676 non-null float64
# C7         610 non-null float64
# T1         681 non-null float64
# T2         681 non-null float64
# T3         681 non-null float64
# T4         681 non-null float64
# T5         681 non-null float64
# S1         681 non-null float64
# S2         681 non-null float64
# S3         681 non-null float64
# dtypes: float64(19), object(3)
# memory usage: 117.3+ KB

# %%
pd.set_option('display.max_rows', None)

# %%
data[(data['P(IPO)']!='-') & (data['P(H)']==np.nan)]
# Out:
# Empty DataFrame
# Columns: [I1, I2, I3, P(IPO), P(H), P(L), P(1Day), C1, C2, C3, C4, C5, C6, C7, T1, T2, T3, T4, T5, S1, S2, S3]
# Index: []
#
# [0 rows x 22 columns]

# %%
data.loc[data['P(L)'] == '-']
# Out:
# Empty DataFrame
# Columns: [I1, I2, I3, P(IPO), P(H), P(L), P(1Day), C1, C2, C3, C4, C5, C6, C7, T1, T2, T3, T4, T5, S1, S2, S3]
# Index: []
#
# [0 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 22 columns):
# I1         682 non-null object
# I2         682 non-null object
# I3         674 non-null object
# P(IPO)     677 non-null float64
# P(H)       672 non-null float64
# P(L)       672 non-null float64
# P(1Day)    660 non-null float64
# C1         660 non-null float64
# C2         660 non-null float64
# C3         646 non-null float64
# C4         660 non-null float64
# C5         676 non-null float64
# C6         676 non-null float64
# C7         610 non-null float64
# T1         681 non-null float64
# T2         681 non-null float64
# T3         681 non-null float64
# T4         681 non-null float64
# T5         681 non-null float64
# S1         681 non-null float64
# S2         681 non-null float64
# S3         681 non-null float64
# dtypes: float64(19), object(3)
# memory usage: 117.3+ KB

# %%
data.head()
# Out:
#      I1                                  I2    I3  P(IPO)  P(H)  P(L)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC  3674    10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC  2834     8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC  2834     7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC  2834    11.5  16.0  14.0
# 4  ACLI     AMERICAN COMMERCIAL LINES INC.   4492    21.0  21.0  19.0
#
#      P(1Day)     C1   C2    C3  ...          C6       C7     T1       T2  \
# 0  11.870000  122.0  1.0  3.43  ...  10600000.0   51.345  470.0  12719.0
# 1   7.250000  259.0  0.0 -1.62  ...   2400000.0   25.936  791.0  21792.0
# 2   6.700000   90.0  1.0 -1.24  ...   5000000.0    7.378  201.0   5262.0
# 3  12.390000  209.0  1.0 -0.91  ...   4500000.0    8.526  328.0   8259.0
# 4  56.599998   80.0  1.0  0.07  ...   8250000.0  632.298  572.0  14830.0
#
#         T3     T4      T5    S1     S2     S3
# 0  11560.0  301.0   690.0  62.0  117.0  139.0
# 1  19585.0  510.0  1120.0  71.0  242.0  237.0
# 2   4785.0  128.0   325.0  61.0   33.0   60.0
# 3   7574.0  177.0   509.0  80.0   59.0  110.0
# 4  13176.0  336.0   720.0  67.0  149.0  167.0
#
# [5 rows x 22 columns]

# %%
data['P(1Day)'].mean()
# Out:
# 25.934766149358605

# %%
data['P(IPO)'].mean()
# Out:
# 13.837666174298375

# %% [markdown]
# ### ASSUMPTION P(H) is generally higher than P(IPO)

# %%
data = data.replace('-',np.nan)
data['IPO/H_dist'] = data['P(H)'] - data['P(IPO)'] 
data['IPO/H_dist'].median()
# Out:
# 1.0

# %%
data['IPO/L_dist'] = data['P(IPO)'] - data['P(L)']
data['IPO/L_dist'].median()
# Out:
# 0.5

# %%
data['H/L_dist'] = data['P(H)'] - data['P(L)'] 
data['H/L_dist'].median()
# Out:
# 2.0

# %% [markdown]
# ## ASSUMPTION P(1Day) usually larger

# %%
data['P(IPO)/P(1Day)_dist'] = data['P(1Day)'] - data['P(IPO)'] 
data['P(IPO)/P(1Day)_dist'].median()
# Out:
# 0.8999999999999995

# %% [markdown]
# # I3 dashes and zereos

# %%
data['I2'] = data['I2'].str.strip()

# %%
data.loc[data['I2'] == 'CHINA CGAME, INC.', 'I3'] = 1600
data.loc[data['I2'] == 'CHINA CGAME, INC.']
# Out:
#       I1                 I2    I3  P(IPO)  P(H)  P(L)  P(1Day)  C1  C2  C3  \
# 490  RCH  CHINA CGAME, INC.  1600     3.5   NaN   NaN      NaN NaN NaN NaN
#
#      ...        C6  C7     T1      T2      T3     T4     T5    S1    S2    S3
# 490  ...  737000.0 NaN  322.0  9820.0  8893.0  230.0  410.0  61.0  92.0  91.0
#
# [1 rows x 22 columns]

# %%
data.loc[data['I2'] == 'Access to Money, Inc.', 'I3'] = 7011
data.loc[data['I2'] == 'Access to Money, Inc.']
# Out:
#        I1                     I2    I3  P(IPO)  P(H)  P(L)  P(1Day)  C1  C2  \
# 597  TRMM  Access to Money, Inc.  7011     NaN   NaN   NaN      NaN NaN NaN
#
#      C3  ...  C6  C7     T1       T2       T3     T4     T5    S1     S2    S3
# 597 NaN  ... NaN NaN  494.0  12004.0  10226.0  277.0  560.0  46.0  100.0  91.0
#
# [1 rows x 22 columns]

# %%
data.loc[data['I2'] == 'BLOUNT INTERNATIONAL INC', 'I3'] = 1600
data.loc[data['I2'] == 'BLOUNT INTERNATIONAL INC']
# Out:
#      I1                        I2    I3  P(IPO)  P(H)  P(L)  P(1Day)  C1  C2  \
# 86  BLT  BLOUNT INTERNATIONAL INC  1600     NaN   NaN   NaN      NaN NaN NaN
#
#     C3  ...  C6  C7     T1       T2       T3     T4     T5    S1     S2     S3
# 86 NaN  ... NaN NaN  538.0  12732.0  11126.0  301.0  631.0  94.0  172.0  116.0
#
# [1 rows x 22 columns]

# %%
data.loc[data['I2'] == 'GLOBAL SIGNAL INC', 'I3'] = 3577
data.loc[data['I2'] == 'GLOBAL SIGNAL INC']
# Out:
#       I1                 I2    I3  P(IPO)  P(H)  P(L)  P(1Day)  C1  C2  C3  \
# 268  GSL  GLOBAL SIGNAL INC  3577    18.0   NaN   NaN      NaN NaN NaN NaN
#
#      ...         C6  C7     T1       T2       T3     T4     T5    S1     S2  \
# 268  ...  7000000.0 NaN  631.0  19479.0  17409.0  451.0  976.0  71.0  252.0
#
#         S3
# 268  155.0
#
# [1 rows x 22 columns]

# %%
#data[data['I2'] == 'Access to Money, Inc.']['I3'] = data[data['I2'] == 'Access to Money, Inc.']['I3']=7011

# %% [markdown]
# CHINA CGAME, INC.	0.0 --> Arhitecture --> 1600
# Access to Money, Inc.	0.0 --> 7011.0
# BLOUNT INTERNATIONAL INC	 1600
# GLOBAL SIGNAL INC	0.0 --> 3577.0
# National American University Holdings, Inc.	0.0 --> 8221.0
# ADCARE HEALTH SYSTEMS, INC	 8099
# TRAVELZOO INC	0.0 --> 7374.0
# KKR Financial Holdings LLC	 7011.0

# %%
174	Dolby Laboratories, Inc.	 3672.0
187	DTS, INC.	3672.0
499	RealD Inc.	 3672.0
620	UNIVERSAL POWER GROUP	3674.0

# %%
i2_i3 = data[['I2','I3']]
i2_i3 = i2_i3.sort_values('I3')
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-18a5401c473c> in <module>
#       1 i2_i3 = data[['I2','I3']]
# ----> 2 i2_i3 = i2_i3.sort_values('I3')
#       3 pd.set_option('display.max_columns', 30)
#       4 pd.set_option('display.max_rows', None)
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    5012
#    5013             indexer = nargsort(
# -> 5014                 k, kind=kind, ascending=ascending, na_position=na_position
#    5015             )
#    5016
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position)
#     258         non_nans = non_nans[::-1]
#     259         non_nan_idx = non_nan_idx[::-1]
# --> 260     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     261     if not ascending:
#     262         indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
data['I3'] = data['I3'].replace('-',np.nan)
data['I3'] = data['I3'].str.strip()
data['I3'] = pd.to_numeric(data['I3'], errors='coerce')

# %%
data.loc[data['I3'] == '-']
# Out:
# Empty DataFrame
# Columns: [I1, I2, I3, P(IPO), P(H), P(L), P(1Day), C1, C2, C3, C4, C5, C6, C7, T1, T2, T3, T4, T5, S1, S2, S3, IPO/H_dist, IPO/L_dist, H/L_dist, P(IPO)/P(1Day)_dist]
# Index: []
#
# [0 rows x 26 columns]

# %%
data.head(10)
# Out:
#      I1                                  I2  I3  P(IPO)  P(H)  P(L)  \
# 0  AATI  ADVANCED ANALOGIC TECHNOLOGIES INC NaN    10.0   9.5   8.5
# 1  ABPI     ACCENTIA BIOPHARMACEUTICALS INC NaN     8.0  10.0   8.0
# 2  ACAD          ACADIA PHARMACEUTICALS INC NaN     7.0  14.0  12.0
# 3  ACHN       ACHILLION PHARMACEUTICALS INC NaN    11.5  16.0  14.0
# 4  ACLI      AMERICAN COMMERCIAL LINES INC. NaN    21.0  21.0  19.0
# 5  ACOM                   Ancestry.com Inc. NaN    13.5  14.5  12.5
# 6  ACOR             ACORDA THERAPEUTICS INC NaN     6.0  13.0  11.0
# 7  ACRX          ACELRX PHARMACEUTICALS INC NaN     5.0  14.0  12.0
# 8  ACTV                  ACTIVE NETWORK INC NaN    15.0  18.0  16.0
# 9   ACW                       ACCURIDE CORP NaN     9.0  19.0  17.0
#
#      P(1Day)     C1   C2    C3  ...       T3     T4      T5    S1     S2  \
# 0  11.870000  122.0  1.0  3.43  ...  11560.0  301.0   690.0  62.0  117.0
# 1   7.250000  259.0  0.0 -1.62  ...  19585.0  510.0  1120.0  71.0  242.0
# 2   6.700000   90.0  1.0 -1.24  ...   4785.0  128.0   325.0  61.0   33.0
# 3  12.390000  209.0  1.0 -0.91  ...   7574.0  177.0   509.0  80.0   59.0
# 4  56.599998   80.0  1.0  0.07  ...  13176.0  336.0   720.0  67.0  149.0
# 5  14.200000   94.0  1.0  0.06  ...  13934.0  328.0   815.0  62.0   96.0
# 6   6.720000  128.0  1.0 -1.87  ...  13953.0  379.0   698.0  82.0  106.0
# 7   4.550000   91.0  0.0 -0.74  ...  10056.0  276.0    -1.0  55.0  120.0
# 8  15.900000  100.0  1.0 -0.51  ...  13463.0  335.0   917.0  58.0  124.0
# 9   0.000000  106.0  1.0  1.49  ...   8107.0  198.0   459.0  81.0   90.0
#
#       S3  IPO/H_dist  IPO/L_dist  H/L_dist  P(IPO)/P(1Day)_dist
# 0  139.0        -0.5         1.5       1.0             1.870000
# 1  237.0         2.0         0.0       2.0            -0.750000
# 2   60.0         7.0        -5.0       2.0            -0.300000
# 3  110.0         4.5        -2.5       2.0             0.890000
# 4  167.0         0.0         2.0       2.0            35.599998
# 5  181.0         1.0         1.0       2.0             0.700000
# 6  135.0         7.0        -5.0       2.0             0.720000
# 7  122.0         9.0        -7.0       2.0            -0.450000
# 8  234.0         3.0        -1.0       2.0             0.900000
# 9  147.0        10.0        -8.0       2.0            -9.000000
#
# [10 rows x 26 columns]

# %%
data.loc[data['C1'] == '-']

# %%
# -1 values in data frame
data[data['T5']==-1]

# %%
# -1 values in data frame
data[data['S1']==-1]

# %%
# 0 values 
data[data['P(H)']==0]

# %%
# 0 values 
data[data['T2']==0]

# %%
# 0 values 
data[data['T3']==0]

# %%
# 0 values 
data[data['T4']==0]

# %%
# 0 values 
data[data['C2']==0]

# %%
# 0 values 
data[data['C3']==0]

# %%
# 0 values 
data[data['P(1Day)']==0]

# %%
# P(H) < P(L)
data[data['P(H)'] < data['P(L)']]

# %% [markdown]
# # Imputation
# ### Decide on the order + different pipelines
# - replace dashes (-), 0, -1, P(H) < P(L) with NaN
# - number and % of missing data<br>
#     - percent_missing = df.isnull().sum() * 100 / len(df)<br>
#     missing_value_df = pd.DataFrame({'column_name': df.columns,'percent_missing': percent_missing})
# - make them a seperate columns
#
# - correct dtype<br>
# - column calculation
#     - the problem probably was because we made calculations for new columns before imputing (so first impute then calculate new columns)
#
# Methods:
# 1. bbfill
# 2. ffill
# 3. median
# 4. mean
# 5. mode
# 6. Treating missing as seperate value (new column/binary value)
# 7. Infer Baysen/classification tree's
#     - http://nadbordrozd.github.io/blog/2017/03/05/missing-data-imputation-with-bayesian-networks/
#     - https://pypi.org/project/predictive_imputer/
#     - https://www.analyticsvidhya.com/blog/2016/03/tutorial-powerful-packages-imputing-missing-values/
#     - https://xgboost.readthedocs.io/en/latest/
#     -
# 8. Binning??

# %% [markdown]
# # Descriptive
# 1. https://www.dataquest.io/blog/basic-statistics-with-python-descriptive-statistics/
# - .describe()
# - scipy.stats.describe(y, ddof=1, bias=False)
# - https://realpython.com/python-statistics/
#
#
# Some questions we could also answer: (NOT REQUIRED)
# - how did companies do/were rated based on their EPS?
# - does it have any effect on a company depending on the number of days its in the IPO process
# - does higher IPO price offer better performance/outlook
# - in what condition the company is (EPS, earnings...) based on how many shares they sell
# - does underwriter rating have any effect and is it correlated with positive/neg words, word lenght etc.
# - Lower price more shares? higher earnings less shares?

# %% [markdown]
# # CORRELATION and simple plots
# - https://realpython.com/python-statistics/ (Towards the bottom)
# - also in lectures that professors posted

# %% [markdown]
# # Normality Test
# - https://machinelearningmastery.com/a-gentle-introduction-to-normality-tests-in-python/
#
# - Histogram
# - Quantile-Quantile Plot
# - Statistical Normality Tests
# - Shapiro-Wilk Test

# %% [markdown]
# # Normalization

# %% [markdown]
# # Standardization

# %% [markdown]
# # Discretization

# %% [markdown]
# # Conversion

# %% [markdown]
# # Outliers

# %% [markdown]
# # Data Reduction

# %% [markdown]
# # Extra

# %%
# first count how many 0's
data = data.astype(str)
data['P(1Day)'] = data['P(1Day)'].str.strip()
data['P(1Day)'] = data['P(1Day)'].replace('-', 0)
data['P(1Day)'] = data['P(1Day)'].astype(float)

# %%
data = data.astype(str)
data = data.replace('-',0)
data[['P(IPO)','P(H)','P(L)','P(1Day)','C1','C3','C4','C5','C6','C7','T1','T2','T3','T4','T5','S1','S2','S3']] = data[['P(IPO)','P(H)','P(L)','P(1Day)','C1','C3','C4','C5','C6','C7','T1','T2','T3','T4','T5','S1','S2','S3']].astype(float)

# %%
data['C2'] = data['C2'].astype(int)

# %%
data.info()

# %%
# 
data['T2'].value_counts()

# %%
# similarities between different null values 
sim = data[data['P(1Day)']==0]

# %% [markdown]
# P(mid) = (P(H)+P(L))/2

# %%
# P(mid) calculation and add it to the column 
data['P(mid)'] = (data['P(H)'] - data['P(L)'])/2

# %%
data.info()

# %% [markdown]
# # this will be different after imputation

# %%
# targets to be calculated
# make it equal to P(IPO) then we will just replace
data['Y1'] = data['P(IPO)']
data['Y2'] = data['P(IPO)']

# replace Y1 and change dtype to binary
data.loc[(data['Y1'] < data['P(mid)']),'Y1'] = 1
data.loc[(data['Y1'] > data['P(mid)']),'Y1'] = 0
data['Y1'] = data['Y1'].astype(int)

# replace Y2
data.loc[(data['Y2'] < data['P(1Day)']),'Y2'] = 1
data.loc[(data['Y2'] > data['P(1Day)']),'Y2'] = 0
data['Y2'] = data['Y2'].astype(int)

# Control values to be calculated
data['C3`'] = data['C3']
data['C3`'] = np.where((data['C3'] > 0),1,data['C3`'])
data['C3`'] = np.where((data['C3'] < 0),0,data['C3`'])
data['C3`'] = data['C3`'].astype(int)

data['C5`'] = data['C5']/data['C6']


# % SIGN??
data['C6calc'] = ((data['P(IPO)'] - data['P(mid)']) / data['P(mid)']) * 1
data['C6`'] = 0
data['C6`'] = np.where((data['P(IPO)'] > data['P(mid)']),data['C6calc'],data['C6`'])
data['C6`'] = np.where((data['P(IPO)'] < data['P(mid)']),0,data['C6`'])

data.head(20)

# %%
sim_missing_val = data[(data['P(1Day)']==0) & (data['P(IPO)']==0) & (data['P(H)']==0)].count()

# %%
# number of zeros in each column 
(data == 0).astype(int).sum(axis=0)

# %%
# Number of non-zero values 
data.astype(bool).sum(axis=0)

# %%
data.head()

# %%
# replace with nulls
# maybe we can run it with zeros/np.nan
cols = ["P(IPO)","P(H)","P(L)","P(1Day)","C1",'C2','C3','C4','C5','C6','C7','T1','T2','T3','T4','T5','S1','S2','S3']
data[cols] = data[cols].replace({0:np.nan})

# Imputate with median
# check if it works right 
data[cols]=data[cols].fillna(data[cols].median())
#.iloc[0]
data['C5'] = data['C5'].fillna(data['C5'].median())

# display
data.head(12)

# %%
data.isnull().sum()

# %%
data.info()

# %%
import matplotlib.pyplot as plt
plt.hist(data['P(IPO)'])
plt.show()

# %%
pd.plotting.scatter_matrix(data[["P(IPO)","P(H)","P(L)"]], figsize=(14,14), hist_kwds={'bins':8}, alpha=.5, marker='o', s=50)

# %%
no_object = data.select_dtypes(exclude=['object'])

# %%
no_object.values

# %%
# normalize with min/max
x = no_object.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled)

# %%
# normalization with sklearn 
from sklearn import preprocessing
# Normalize P(IPO) column (1 column)
x_array = np.array(data['P(IPO)'])
normalized_X = preprocessing.normalize([x_array])

# %%
normalized_X

# %%
# mean normalization
normalized_df=(df-df.mean())/df.std()

# min/max normalization 
normalized_df=(df-df.min())/(df.max()-df.min())

# Note that `select_dtypes` returns a data frame. We are selecting only the columns
numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols].apply(zscore)

# Standardization/normalization

# %%
# STANDARDIZATION
# Get column names first
names = df.columns
# Create the Scaler object
scaler = preprocessing.StandardScaler()
# Fit your data on the scaler object
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=names)

# %%
# Correlation Analysis

# %%
# WHEN YOU HAVE ALL THE CALCULATIONS AND VARIATIONS DOWN DECIDE ON THE ORDER OF THE PROCESSING AND WHAT TO TRY AFTER
# THEN RUN THE MODEL
